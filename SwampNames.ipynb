# %%
# import libraries
from urllib.request import urlopen
from bs4 import BeautifulSoup
import csv

# %%
url = "http://dos.sunbiz.org/scripts/ficregl.exe?action=REGPRE&docnum=G11000060279"

# %%
data_list = []
date_list = []

# %%
count = 1
while (count < 2):
    page = urlopen(url)
    soup = BeautifulSoup(page, "html.parser") # parse the html using beautiful soup and store in variable `soup`
    divs = soup.findAll("table", {"summary": "This table displays the name lists for the 6 column headings."}) # Take out the <div> of otherInfo and get its value
    x = len(data_list)
    for div in divs:
        rows = div.findAll('tr')
        for row in rows[1:]:
            data_list.append(row.findAll('td'))
    for j in range(x, len(data_list)):
        for k in range(0, len(data_list[j])):
            data_list[j][k] = data_list[j][k].text.strip()
            
    urls = soup.findAll('a')
    for i in range(2, len(urls)-4):
        link = "http://dos.sunbiz.org" + urls[i]['href']
        date_page = urlopen(link)
        small_soup = BeautifulSoup(date_page, "html.parser")
        table = small_soup.find('table', attrs={'summary': 'This table contains filing information.'})
        td_list = table.findAll('td')
        date_list.append([td_list[6].text.strip()])
    
    temp = [div.find('a') for div in soup.find('div', attrs={'class':'search-nav bottom'})]
    end = temp[1].find_next('a')
    url = "http://dos.sunbiz.org" + end['href']
    if "swamp" not in data_list[-1][0].lower():
        count = 2

# %%
final_list = []

# %%
for i in range (0, len(data_list)):
    final_list.append(data_list[i] + date_list[i])

# %%
final_list
# Out:
# [['THE SWAMP',
#   '1551 FORUM PLACE',
#   'WEST PALM BEACH',
#   'FL',
#   'PALM BEACH',
#   'E',
#   '01/12/2009'],
#  ['THE SWAMP',
#   '1624 NW 1ST AVE',
#   'GAINESVILLE',
#   'FL',
#   'ALACHUA',
#   'A',
#   '09/09/2010'],
#  ['THE SWAMP',
#   '1642 W. UNIVERSITY AVENUE',
#   'GAINESVILLE',
#   'FL',
#   'ALACHUA',
#   'E',
#   '09/21/1994'],
#  ['THE SWAMP', 'PO BOX 5497', 'DESTIN', 'FL', 'OKALOOSA', 'E', '05/23/2012'],
#  ['SWAMPADS',
#   '9601 WEST BROWARD BLVD',
#   'PLANTATION',
#   'FL',
#   'BROWARD',
#   'E',
#   '04/11/2003'],
#  ['SWAMP AIR SERVICE',
#   'PO BOX 1576',
#   'POLK CITY',
#   'FL',
#   'POLK',
#   'E',
#   '08/10/2005'],
#  ['SWAMP ART TOO',
#   '324 S 9TH ST',
#   'FERNANDINA BEACH',
#   'FL',
#   'NASSAU',
#   'E',
#   '09/04/2007'],
#  ['SWAMP ART TOO',
#   '5603 GREGG STREET',
#   'FERNANDINA BEACH',
#   'FL',
#   'NASSAU',
#   'A',
#   '02/01/2018'],
#  ['SWAMP ASS CUSTOMS',
#   '835 35 CT SW',
#   'VERO BEACH',
#   'FL',
#   'INDIAN RIVER',
#   'E',
#   '03/19/2008'],
#  ['SWAMP BIKES ATV',
#   'P.O. BOX 141',
#   'EVERGLADES CITY',
#   'FL',
#   'COLLIER',
#   'E',
#   '04/25/2005'],
#  ['SWAMPBILLIE MUSIC PUBLISHING',
#   '2635 MARTIN AVE',
#   'LAKELAND',
#   'FL',
#   'MULTIPLE',
#   'E',
#   '11/25/2008'],
#  ['SWAMPBILLY WORM FARM',
#   '26400 BLUEMOON RD.',
#   'PAISLEY',
#   'FL',
#   'LAKE',
#   'E',
#   '08/08/2000'],
#  ['SWAMP BLAZE RECORDS',
#   '168 PALMYRA DRIVE',
#   'ORLANDO',
#   'FL',
#   'ORANGE',
#   'E',
#   '10/14/2003'],
#  ['SWAMP BLOSSOM',
#   '19451 SW 236 STREET',
#   'HOMESTEAD',
#   'FL',
#   'MIAMI-DADE',
#   'E',
#   '10/25/1999'],
#  ['SWAMPBOARD.COM',
#   '2930 SW 23RD TERRACE',
#   'GAINESVILLE',
#   'FL',
#   'ALACHUA',
#   'E',
#   '11/21/2005'],
#  ['SWAMP BOIL',
#   '2001NW 13TH STREET SUITE 10',
#   'GAINESVILLE',
#   'FL',
#   'ALACHUA',
#   'A',
#   '09/28/2017'],
#  ['SWAMPBOI RECORDS',
#   '14761 SW 175TH COURT',
#   'INDIANTOWN',
#   'FL',
#   'MULTIPLE',
#   'E',
#   '07/09/2012'],
#  ['SWAMPBOTS FTC 10497',
#   '9857 NORTHWEST 136 DR.',
#   'ALACHUA',
#   'FL',
#   'MULTIPLE',
#   'A',
#   '12/20/2016'],
#  ['SWAMP BOYZ',
#   '3720 WEST JEFFERSON ST.',
#   'ORLANDO',
#   'FL',
#   'MULTIPLE',
#   'E',
#   '09/02/2006'],
#  ['SWAMP BUGGIES OF FLORIDA',
#   'P.O. BOX 2955',
#   'LABELLE',
#   'FL',
#   'HENDRY',
#   'E',
#   '06/16/2011'],
#  ['SWAMP BUGGIES OF FLORIDA',
#   'P.O. BOX 2955',
#   'LABELLE',
#   'FL',
#   'HENDRY',
#   'V',
#   '06/16/2011'],
#  ['SWAMP CHALLENGE',
#   '1126 NW 2ND ST.',
#   'GAINESVILLE',
#   'FL',
#   'ALACHUA',
#   'A',
#   '08/14/2017'],
#  ['SWAMP CHOPPERS',
#   '3435 RED OAK CIRCLE EAST',
#   'ORANGE PARK',
#   'FL',
#   'CLAY',
#   'E',
#   '03/20/2001'],
#  ['SWAMP CITY FITNESS',
#   '217 SE 1ST AVE',
#   'OCALA',
#   'FL',
#   'ALACHUA',
#   'A',
#   '02/20/2018'],
#  ['SWAMP CITY SERVICES',
#   '821 NW 39TH ST',
#   'GAINESVILLE',
#   'FL',
#   'ALACHUA',
#   'A',
#   '06/13/2013'],
#  ['SWAMPCOAST GRAPHICS',
#   '6305 ALDERWOOD STREET',
#   'SPRING HILL',
#   'FL',
#   'HERNANDO',
#   'E',
#   '09/12/2000'],
#  ['SWAMP CRACKER OUTFITTERS',
#   '520 N STONE ST',
#   'DELAND',
#   'FL',
#   'VOLUSIA',
#   'E',
#   '03/01/2011'],
#  ['SWAMP CREEK SAWMILL AND STAKE COMPANY',
#   '10494 FL-GA HWY.',
#   'HAVANA',
#   'FL',
#   'GADSDEN',
#   'A',
#   '02/27/2002'],
#  ['SWAMP CRITTER TASTE CO',
#   '126 WHISPERING WINDS RD',
#   'PALATKA',
#   'FL',
#   'PUTNAM',
#   'E',
#   '11/23/2011'],
#  ['SWAMP CRITTER TASTSE COMPANY',
#   'P O BOX 1096',
#   'HOLLISTER',
#   'FL',
#   'PUTNAM',
#   'A',
#   '12/11/2015'],
#  ['SWAMP CUTS',
#   'P.O. BOX 607',
#   'MIDDLEBURG',
#   'FL',
#   'DUVAL',
#   'E',
#   '09/07/2001'],
#  ['SWAMP DADDY AIRBOATS AND FABRICATION',
#   'P.O BOX 4',
#   'ALTOONA',
#   'FL',
#   'LAKE',
#   'A',
#   '06/19/2016'],
#  ['SWAMP DAWG BBQ & GRILL',
#   '3580 OAKTREE LN',
#   'PACE',
#   'FL',
#   'MULTIPLE',
#   'E',
#   '01/31/2012'],
#  ['SWAMP DIVA DESIGNS',
#   '18051 S.E. 52ND ST',
#   'OCKLAWAHA',
#   'FL',
#   'MARION',
#   'A',
#   '09/01/2016'],
#  ['SWAMP DOGS',
#   '5090 FLORIDA PALM AVE',
#   'COCOA',
#   'FL',
#   'MULTIPLE',
#   'A',
#   '06/10/2017'],
#  ['SWAMP DONKEY AIRBOAT RIDES',
#   '411 MERCER ST NW',
#   'PALM BAY',
#   'FL',
#   'BREVARD',
#   'A',
#   '02/14/2017'],
#  ['SWAMPDONKEY AQUATICS',
#   '12536 PECAN TREE DR',
#   'HUDSON',
#   'FL',
#   'MULTIPLE',
#   'A',
#   '11/01/2007'],
#  ['SWAMP DONKEY LAWN SERVICES',
#   '7239 SE 80TH STREET',
#   'TRENTON',
#   'FL',
#   'MULTIPLE',
#   'A',
#   '02/18/2018'],
#  ['THE SWAMP DONKEYS',
#   '417 AVALON BLVD',
#   'ORLANDO',
#   'FL',
#   'ORANGE',
#   'A',
#   '07/22/2017'],
#  ['SWAMP DRAGON TOBACCO AND GIFTS',
#   '1221 W. UNIVERSITY AVE',
#   'GAINESVILLE',
#   'FL',
#   'ALACHUA',
#   'E',
#   '02/12/2011'],
#  ['SWAMPERS BBQ',
#   '1515 SILVER BELL LN',
#   'ORANGE, PARK',
#   'FL',
#   'MULTIPLE',
#   'E',
#   '09/21/2004'],
#  ['SWAMP EYES',
#   '407 NW DESOTO STREET',
#   'LAKE CITY',
#   'FL',
#   'COLUMBIA',
#   'E',
#   '06/26/2004'],
#  ['SWAMP FABRICATIONS',
#   '4655 LAKE LOWERY ROAD',
#   'HAINES CITY',
#   'FL',
#   'POLK',
#   'A',
#   '01/22/2013'],
#  ['SWAMP FEVER', 'P.O. BOX 141', 'ARCHER', 'FL', 'ALACHUA', 'E', '05/12/2000'],
#  ['SWAMPFOX AIRBOATS',
#   '162 RANDIA DR',
#   'ORLANDO',
#   'FL',
#   'ORANGE',
#   'E',
#   '09/15/1998'],
#  ['SWAMP FOX AUTOMOTIVE',
#   '4983 SWAMP FOX ROAD',
#   'TALLAHASSEE',
#   'FL',
#   'LEON',
#   'E',
#   '05/08/2003'],
#  ['SWAMP FOX SERVICES',
#   '16318 SW TWO WOOD WAY',
#   'INDIANTOWN',
#   'FL',
#   'MARTIN',
#   'A',
#   '08/28/2017'],
#  ['SWAMPFOX TAXIDERMY',
#   '2654 SW ACCO RD',
#   'PORT SAINT LUCIE',
#   'FL',
#   'ST. LUCIE',
#   'E',
#   '04/02/2007'],
#  ['SWAMP FOX TRADING',
#   '1304 SW 161ST PLACE',
#   'OCALA',
#   'FL',
#   'MARION',
#   'E',
#   '11/02/2012'],
#  ['SWAMP FROG RACING, LLC',
#   '5630 65TH. AVE. N.',
#   'PINELLAS PARK',
#   'FL',
#   'PINELLAS',
#   'E',
#   '12/29/2007'],
#  ['SWAMP GEAR',
#   '3565 JUSTIN DR.',
#   'PALM HARBOR',
#   'FL',
#   'MULTIPLE',
#   'E',
#   '08/01/2005'],
#  ['SWAMP GIRL SERPENTS',
#   '35030 CHANCEY RD',
#   'ZEPHYRHILLS',
#   'FL',
#   'MULTIPLE',
#   'A',
#   '03/12/2017'],
#  ['SWAMP GRASS GIFTS, GOODIES, & SERVICES',
#   '217 COMMONWEALTH AVE S',
#   'POLK CITY',
#   'FL',
#   'POLK',
#   'E',
#   '10/01/2009'],
#  ['SWAMP-G RECORDS & ENTERTAINMENT',
#   '1580 NW 24TH AVE',
#   'OCALA',
#   'FL',
#   'MARION',
#   'E',
#   '04/27/2001'],
#  ['SWAMP GUIDE',
#   '9 NW 99TH TERR',
#   'GAINESVILLE',
#   'FL',
#   'ALACHUA',
#   'A',
#   '04/11/2013'],
#  ['SWAMP HAWG TRAPPING & BBQ',
#   '121 RODEO ROAD',
#   'ORMOND BEACH',
#   'FL',
#   'VOLUSIA',
#   'A',
#   '12/21/2017'],
#  ['SWAMP HOUSE',
#   '10421 N DAVIS HIGHWAY',
#   'PENSACOLA',
#   'FL',
#   'ESCAMBIA',
#   'A',
#   '12/17/2010'],
#  ['SWAMP HOUSE GRILL',
#   'PO BOX 4175',
#   'ENTERPRISE',
#   'FL',
#   'VOLUSIA',
#   'A',
#   '05/16/2007'],
#  ['SWAMP HOUSE RIVER FRONT GRILL',
#   'PO BOX 4175',
#   'ENTERPRISE',
#   'FL',
#   'VOLUSIA',
#   'A',
#   '02/27/2009'],
#  ['SWAMP ICE',
#   '1441 MANOTAK AVE',
#   'JACKSONVILLE',
#   'FL',
#   'DUVAL',
#   'E',
#   '12/20/2004'],
#  ['SWAMPIE ART',
#   '510 W CHARLOTTE AVE',
#   'EUSTIS',
#   'FL',
#   'MULTIPLE',
#   'E',
#   '01/07/2008'],
#  ['SWAMPIT 4X4',
#   '306 S . KINGSWAY RD.',
#   'SEFFNER',
#   'FL',
#   'HILLSBOROUGH',
#   'A',
#   '03/27/2008'],
#  ['SWAMP JUICE',
#   'JUDY MCCOOMB',
#   'NEWBERRY',
#   'FL',
#   'ALACHUA',
#   'E',
#   '09/20/2012'],
#  ['SWAMPLAND ENTERPRISES',
#   '16302 NORTHWEST 74TH AVENUE',
#   'ALACHUA',
#   'FL',
#   'ALACHUA',
#   'A',
#   '08/25/2014'],
#  ['SWAMPLAND ENTERTAINMENT',
#   '8401 SNOWFIRE DR',
#   'ORLANDO',
#   'FL',
#   'ORANGE',
#   'E',
#   '05/26/2000'],
#  ['SWAMPLANDS OUTFITTERS LLC',
#   '6350 BABCOCK STREET #318',
#   'PALM BAY',
#   'FL',
#   'BREVARD',
#   'E',
#   '09/14/2012'],
#  ['SWAMP LEAGUE RECORDS',
#   '6710 COLLINS RD APT #312',
#   'JACKSONVILLE',
#   'FL',
#   'DUVAL',
#   'E',
#   '10/16/2002'],
#  ['SWAMP LIFE',
#   '250 NW VALENCIA ROAD',
#   'MELBOURNE',
#   'FL',
#   'MULTIPLE',
#   'E',
#   '11/16/2008'],
#  ['SWAMP LIFE',
#   '3205 FOREST BLVD',
#   'JACKSONVILLE',
#   'FL',
#   'DUVAL',
#   'E',
#   '07/09/2008'],
#  ['SWAMP LIFE LURES',
#   '2302 GATEWOOD STREET',
#   'PLANT CITY',
#   'FL',
#   'HILLSBOROUGH',
#   'E',
#   '03/26/2010'],
#  ['SWAMP LIFE MOBLE REPAIR SERVICE',
#   '725 NW 13TH STREET APT. 3115',
#   'GAINESVILLE',
#   'FL',
#   'MULTIPLE',
#   'E',
#   '09/22/2009'],
#  ['SWAMP LILY RECORDS',
#   '412 NORTH 1ST STREET',
#   'JACKSONVILLE BEACH',
#   'FL',
#   'DUVAL',
#   'C',
#   '03/08/2005'],
#  ['SWAMP MONK MUSIC WORKS',
#   '3624 BARBARY DRIVE',
#   'TALLAHASSEE',
#   'FL',
#   'LEON',
#   'E',
#   '08/27/2004'],
#  ['SWAMP  MONK MUSIC WORKS',
#   '3624 BARBARY DRIVE',
#   'TALLAHASSEE',
#   'FL',
#   'LEON',
#   'E',
#   '06/11/2010'],
#  ['SWAMP MONSTER FISHING',
#   '6485 W RICH ST',
#   'CRYSTAL RIVER',
#   'FL',
#   'MULTIPLE',
#   'A',
#   '05/14/2014'],
#  ['SWAMPMONSTERS',
#   '127 N. ROBIN HOOD RD.',
#   'INVERNESS',
#   'FL',
#   'CITRUS',
#   'E',
#   '05/31/2011'],
#  ['SWAMPMUSIC',
#   '5622 FOREST HILLS DR',
#   'HOLIDAY',
#   'FL',
#   'MULTIPLE',
#   'E',
#   '08/16/2003'],
#  ['SWAMPNET',
#   '17668 NW 238TH TER',
#   'HIGHSPRINGS',
#   'FL',
#   'ALACHUA',
#   'A',
#   '06/09/2017'],
#  ['SWAMP NOTES',
#   'PO BOX 90307',
#   'GAINESVILLE',
#   'FL',
#   'ALACHUA',
#   'E',
#   '05/14/1998'],
#  ['SWAMP NUTS',
#   '460 39TH AVE NE',
#   'NAPLES',
#   'FL',
#   'COLLIER',
#   'A',
#   '02/04/2013'],
#  ['SWAMPOAK OUTDOORS',
#   '12731 SERENADE CIR NORTH',
#   'JACKSONVILLE',
#   'FL',
#   'DUVAL',
#   'E',
#   '04/10/2007'],
#  ['SWAMP PILOTS ABT',
#   '12326 165TH RD N',
#   'JUPITER',
#   'FL',
#   'PALM BEACH',
#   'A',
#   '02/27/2015'],
#  ['SWAMP RADIO',
#   '1836 SEAGATE AVE',
#   'NEPTUNE BEACH',
#   'FL',
#   'MULTIPLE',
#   'A',
#   '10/08/2013'],
#  ['SWAMP RAMPS',
#   '1205 COUNTRY CLOSE DRIVE',
#   'LUTZ',
#   'FL',
#   'HILLSBOROUGH',
#   'E',
#   '10/05/2000'],
#  ['SWAMP RAT',
#   '1109 CANAL ST.',
#   'RUSKIN',
#   'FL',
#   'HILLSBOROUGH',
#   'E',
#   '10/30/2006'],
#  ['SWAMP RATS PAINTBALL TEAM',
#   '1140 HUDSON RD',
#   'VENICE',
#   'FL',
#   'MULTIPLE',
#   'E',
#   '09/09/2008'],
#  ['SWAMP RAT TRUCKING',
#   '987 SW SEVEN BRIDGE RD.',
#   'GREENVILLE',
#   'FL',
#   'MADISON',
#   'E',
#   '04/20/1998'],
#  ['SWAMP RAT WOODWORKS',
#   '925 NW 60TH STREET',
#   'GAINESVILLE',
#   'FL',
#   'ALACHUA',
#   'E',
#   '06/17/2007'],
#  ['SWAMP RECORDS',
#   '9910 ALT. A1A , SUITE #711',
#   'PALM BEACH GARDENS',
#   'FL',
#   'PALM BEACH',
#   'E',
#   '12/05/2012'],
#  ['SWAMP RENTALS',
#   '13506 SUMMERPORT VLG PKY',
#   'WINDERMERE',
#   'FL',
#   'ORANGE',
#   'A',
#   '01/23/2010'],
#  ['THE SWAMP RESTAURANT',
#   '1624 NW 1ST AVE',
#   'GAINESVILLE',
#   'FL',
#   'ALACHUA',
#   'A',
#   '03/04/2008'],
#  ['THE SWAMP RESTAURANT & LOUNGE',
#   'P.O. BOX 458',
#   'POMONA PARK',
#   'FL',
#   'PUTNAM',
#   'E',
#   '12/07/2000'],
#  ['SWAMPS BUGGY GRILL',
#   '913 N BARFIELD DR',
#   'MARCO ISLAND',
#   'FL',
#   'COLLIER',
#   'E',
#   '02/27/1998'],
#  ['SWAMP SENTINAL',
#   '3525 BEAUMONT LOOP',
#   'SPRING HILL',
#   'FL',
#   'MULTIPLE',
#   'A',
#   '04/29/2014'],
#  ['SWAMP SENTINAL',
#   '3525 BEAUMONT LOOP',
#   'SPRING HILL',
#   'FL',
#   'MULTIPLE',
#   'V',
#   '04/29/2014'],
#  ['SWAMP SHACK', '220 BASIK DR', 'NAPLES', 'FL', 'COLLIER', 'E', '10/01/2009'],
#  ['SWAMP SHACK FLA',
#   'PO BOX 74',
#   'PIERSON',
#   'FL',
#   'VOLUSIA',
#   'E',
#   '08/15/2011'],
#  ['SWAMP SHACK ICE CREAM',
#   '1640 GREGORY DR',
#   'DELTONA',
#   'FL',
#   'ST. JOHNS',
#   'E',
#   '03/25/2003'],
#  ['THE SWAMP SHACK SCHOLARSHIP FUND',
#   '233 OVERBROOK DRIVE',
#   'CASSELBERRY',
#   'FL',
#   'SEMINOLE',
#   'E',
#   '08/05/2006'],
#  ['SWAMP SHINE',
#   '4650 PINE LEVEL WAY',
#   'FT MYERS',
#   'FL',
#   'LEE',
#   'E',
#   '01/24/2009'],
#  ['SWAMP SHOOT',
#   '6130 NW 54TH WAY',
#   'GAINESVILLE',
#   'FL',
#   'MULTIPLE',
#   'E',
#   '04/10/2012'],
#  ['SWAMP SHOTS',
#   '4103 N.W. 59TH AVENUE',
#   'GAINESVILLE',
#   'FL',
#   'ALACHUA',
#   'A',
#   '04/02/2015'],
#  ['SWAMP SHOTS',
#   '765 TURKEY CREEK',
#   'ALACHUA',
#   'FL',
#   'ALACHUA',
#   'C',
#   '01/05/2012'],
#  ['SWAMP SONGS ENTERTAINMENT',
#   '13048 86TH ROAD NORTH',
#   'WEST PALM BEACH',
#   'FL',
#   'PALM BEACH',
#   'E',
#   '03/15/2001'],
#  ['SWAMPSOUTH LAWN CARE AND LANDSCAPING',
#   '4721 NW 15TH AVE APT 2',
#   'MIAMI',
#   'FL',
#   'MIAMI-DADE',
#   'A',
#   '06/26/2013'],
#  ['SWAMP SPORTS CUSTOM METAL FABRICATION',
#   '146 VAUSE TRAIL',
#   'HAWTHORNE',
#   'FL',
#   'PUTNAM',
#   'E',
#   '12/22/2010'],
#  ['SWAMPSTUDIOS',
#   '9910 ALT. A1A , SUITE #711',
#   'PALM BEACH GARDENS',
#   'FL',
#   'PALM BEACH',
#   'E',
#   '12/27/2011'],
#  ['SWAMP SYSTEMS, LLC',
#   '340 SOUTH LEMON AVE.',
#   'WALNUT',
#   'CA',
#   'ALACHUA',
#   'E',
#   '08/25/2006'],
#  ['SWAMP THING MARKETING',
#   '8474 SHADY GLEN DRIVE',
#   'ORLANDO',
#   'FL',
#   'ORANGE',
#   'E',
#   '09/14/2010'],
#  ['THE SWAMP TIMES',
#   '19058 MIAMI BOULEVARD',
#   'FORT MYERS',
#   'FL',
#   'LEE',
#   'E',
#   '02/20/1999'],
#  ['SWAMP TONE STUDIOS',
#   'PASTEL MUSIC INC ATTN: JEFF LAMIROULT',
#   'WEST HOLLYWOOD',
#   'CA',
#   'ORANGE',
#   'E',
#   '07/06/2004'],
#  ['SWAMP TO SEA GUIDE SERVICE',
#   '1421 WEST DREW ST',
#   'LANTANA',
#   'FL',
#   'MULTIPLE',
#   'A',
#   '09/14/2015'],
#  ['SWAMP TOW',
#   '341 VESTA CIRCLE',
#   'MELBOURNE',
#   'FL',
#   'MULTIPLE',
#   'E',
#   '06/29/2011'],
#  ['SWAMP TRANSPORTATION SERVICES',
#   '3301 SW 13TH STREET  APT. E155',
#   'GAINESVILLE',
#   'FL',
#   'ALACHUA',
#   'E',
#   '05/09/2007'],
#  ['THE SWAMP USA',
#   '3947 CLARK RD',
#   'SARASOTA',
#   'FL',
#   'MULTIPLE',
#   'A',
#   '08/14/2017'],
#  ['SWAMPUS PROPERTY SERVICES',
#   '3515 NW 21ST ST',
#   'GAINESVILLE',
#   'FL',
#   'ALACHUA',
#   'E',
#   '06/16/2005'],
#  ['SWAMP WALKERS',
#   '8157 DARTS ST',
#   'BROOKSVILLE',
#   'FL',
#   'HERNANDO',
#   'E',
#   '09/20/2004'],
#  ['SWAMP WASH',
#   '1325 N.W. 53RD AVENUE, SUITE E',
#   'GAINESVILLE',
#   'FL',
#   'ALACHUA',
#   'A',
#   '05/29/2015'],
#  ['SWAMP WASH',
#   '2101 NORTHWEST 142 AVENUE',
#   'GAINESVILLE',
#   'FL',
#   'ALACHUA',
#   'C',
#   '02/01/2000'],
#  ["SWAMP WATER BOY'S",
#   '1674 BELMONT WOODS DR',
#   'MULBERRY',
#   'FL',
#   'POLK',
#   'E',
#   '10/20/2005'],
#  ['SWAMP WATER CAFE',
#   '29900 GATOR TAIL TRAIL',
#   'CLEWISTON',
#   'FL',
#   'HENDRY',
#   'A',
#   '11/24/2015'],
#  ['SWAMP WATER DAWGS',
#   'P.O. BOX 2393',
#   'OCALA',
#   'FL',
#   'MULTIPLE',
#   'A',
#   '05/02/2013'],
#  ['SWAMP WATER DECAL & DESIGNS',
#   '4475 LOWER MEADOW ROAD',
#   'MULBERRY',
#   'FL',
#   'POLK',
#   'A',
#   '09/03/2013'],
#  ['SWAMPWATER TRUSTEE SERVICES',
#   '6100 GULFPORT BLVD. SOUTH',
#   'GULFPORT',
#   'FL',
#   'PINELLAS',
#   'A',
#   '05/02/2013'],
#  ['SWAMPY ACRES',
#   'P.O. BOX 7714',
#   'SEBRING',
#   'FL',
#   'HIGHLANDS',
#   'E',
#   '10/04/2000'],
#  ['SWAMPY GATOR KNOCKERBALLS LLC',
#   '4002 NW 32ND STREET',
#   'GAINESVILLE',
#   'FL',
#   'ALACHUA',
#   'A',
#   '03/14/2017'],
#  ['SWAMPYS BAR & GRILLE',
#   '3821 NW BLITCHTON RD.',
#   'OCALA',
#   'FL',
#   'MARION',
#   'C',
#   '03/29/2012'],
#  ["SWAMPY'S CAJUN BAR AND GRILL",
#   '4305 HWY 98 BUS W',
#   'PANAMA CITY',
#   'FL',
#   'BAY',
#   'A',
#   '03/18/2014'],
#  ['SWAMPYS GRUB AND PUB',
#   '20049 E. PENNSYLVANIA AVE.',
#   'DUNNELLON',
#   'FL',
#   'MARION',
#   'E',
#   '04/27/2010'],
#  ['THE SWAMPY TONK BAR',
#   '10531 NW TWIN OAKS LN.',
#   'CLARKSVILLE',
#   'FL',
#   'CALHOUN',
#   'E',
#   '08/05/2010'],
#  ['SWAN, INC', '21409 SHERIDAN RUN', 'ESTERO', 'FL', 'LEE', 'E', '09/09/2008'],
#  ['SWAN', '6438 KAHANA WAY', 'SARASOTA', 'FL', 'SARASOTA', 'A', '07/05/1996'],
#  ['SWAN AGE REVERSAL CENTERS',
#   '3301 BONITA BEACH RD #106',
#   'BONITA SPRINGS',
#   'FL',
#   'MULTIPLE',
#   'A',
#   '12/26/2014'],
#  ['SWAN AGE REVERSAL CENTER OF VENICE AND LAKEWOOD RANCH',
#   'P. O. BOX 3700',
#   'PLACIDA',
#   'FL',
#   'MULTIPLE',
#   'A',
#   '09/27/2016'],
#  ['SWAN ALTERATIONS & REPAIRS',
#   '1462 OAK HILL RD.',
#   'GULF BREEZE',
#   'FL',
#   'SANTA ROSA',
#   'A',
#   '12/11/2003'],
#  ['SWAN ANTI AGING CENTER OF LAKEWOOD RANCH',
#   'P.O.BOX 3418',
#   'PLACIDA',
#   'FL',
#   'MULTIPLE',
#   'A',
#   '09/27/2016'],
#  ['SWAN ANTI AGING CENTER OF VENICE',
#   'P. O. BOX 3700',
#   'PLACIDA',
#   'FL',
#   'MULTIPLE',
#   'A',
#   '09/27/2016'],
#  ['SWAN ASSET MANAGEMENT',
#   '201 GRAND POINTE DR',
#   'PALM BEACH GARDENS',
#   'FL',
#   'PALM BEACH',
#   'E',
#   '02/15/2007'],
#  ['SWAN ASSET MANAGEMENT',
#   '201 GRAND POINTE DRIVE',
#   'PALM BEACH GARDENS',
#   'FL',
#   'PALM BEACH',
#   'E',
#   '06/07/2001'],
#  ['SWAN AUTOMOTIVE',
#   '646 2ND LANE',
#   'VERO BEACH',
#   'FL',
#   'INDIAN RIVER',
#   'A',
#   '01/13/2017']]

# %%
# Out:
# [['THE GATOR', 'P.O. BOX 14257', 'GAINESVILLE', 'FL', 'MULTIPLE', 'A'],
#  ['GATOR', 'PO BOX 270291', 'TAMPA', 'FL', 'HILLSBOROUGH', 'A'],
#  ['GATOR1COMPUTERS',
#   '7013 SE 222ND STREET',
#   'HAWTHORNE',
#   'FL',
#   'MULTIPLE',
#   'E'],
#  ['GATOR 200 CLUB', '5210 NW 59TH LANE', 'GAINESVILLE', 'FL', 'ALACHUA', 'E'],
#  ['GATOR21 AUTO TECH SERVICE',
#   '7220 SW 34TH STREET ROAD',
#   'MIAMI',
#   'FL',
#   'MULTIPLE',
#   'E'],
#  ['GATOR ADVENTURE PARK',
#   '2856 FALLING TREE CIRCLE',
#   'ORLANDO',
#   'FL',
#   'MULTIPLE',
#   'E'],
#  ['GATOR ADVENTURE PRODUCTIONS',
#   '2856 FALLING TREE CIRCLE',
#   'ORLANDO',
#   'FL',
#   'MULTIPLE',
#   'A'],
#  ['GATOR ADVENTURES',
#   '292 SHADOWRIDGE COURT',
#   'MARCO ISLAND',
#   'FL',
#   'MULTIPLE',
#   'E'],
#  ['GATORADVENTURES.COM',
#   '138 PALM COAST PKWY NE #121',
#   'PALM COAST',
#   'FL',
#   'FLAGLER',
#   'E'],
#  ['GATOR-AERODYNAMICS MIUS I CAR CRASH IN USA',
#   '101-NE THIRD AVENUE SUITE 1500',
#   'FT LAUDERDALE',
#   'FL',
#   'MULTIPLE',
#   'A'],
#  ['GATOR AFFILIATES', '6610 YARDLEY WAY', 'TAMPA', 'FL', 'HILLSBOROUGH', 'A'],
#  ['GATOR AGENCY', 'P.O. BOX 1464', 'LEHIGH ACRES', 'FL', 'LEE', 'A'],
#  ['GATOR AIR', '500 TERMINAL DRIVE', 'NAPLES', 'FL', 'COLLIER', 'E'],
#  ['GATOR AIR',
#   '602 SW 77TH WAY, NORTH PERRY AIRPORT',
#   'PEMBROKE PINES',
#   'FL',
#   'BROWARD',
#   'C'],
#  ['GATOR AIR CONDITIONING & HEATING SERVICE, INC.',
#   '546 HEATHER BRITE CIRCLE',
#   'APOPKA',
#   'FL',
#   'ORANGE',
#   'E'],
#  ['GATOR AIR CONDITIONING AND HEATING SERVICES',
#   '546 HEATHER BRITE CIRCLE',
#   'APOPKA',
#   'FL',
#   'ORANGE',
#   'A'],
#  ['GATOR AIR CONDITIONING AND PLUMBING',
#   '6216 28TH ST E',
#   'BRADENTON',
#   'FL',
#   'MANATEE',
#   'A'],
#  ['GATOR AIR CONDITIONING AND PLUMBING',
#   '6216 28TH STREET EAST',
#   'BRADENTON',
#   'FL',
#   'MULTIPLE',
#   'A'],
#  ['GATOR AIR CONDITIONING & REFRIGERATION',
#   '8567 PINTO DRIVE',
#   'LAKE WORTH',
#   'FL',
#   'MULTIPLE',
#   'E'],
#  ['GATOR AIR & ENERGY', '345 NW 48 BLVE', 'GAINESVILLE', 'FL', 'ALACHUA', 'E'],
#  ['GATOR AIR AND PLUMBING',
#   '6216 28TH ST E',
#   'BRADENTON',
#   'FL',
#   'MANATEE',
#   'C'],
#  ['GATOR ALARM', 'P.O. BOX 1151', 'GAINESVILLE', 'FL', 'MULTIPLE', 'E'],
#  ['GATORALE', '1401 FORUM WAY', 'WEST PALM BEACH', 'FL', 'PALM BEACH', 'A'],
#  ['GATORALE BOLD',
#   '1551 FORUM PLACE',
#   'WEST PALM BEACH',
#   'FL',
#   'PALM BEACH',
#   'E'],
#  ['GATORALE LIGHT',
#   '1551 FORUM PLACE',
#   'WEST PALM BEACH',
#   'FL',
#   'PALM BEACH',
#   'E'],
#  ['GATOR ALLEY', '4137 W VINE ST', 'KISSIMMEE', 'FL', 'OSCEOLA', 'E'],
#  ['GATOR ALLEY ENVIRONMENTAL SERVICES',
#   '4606 PRESTON WOODS DR',
#   'VALRICO',
#   'FL',
#   'MULTIPLE',
#   'A'],
#  ['GATOR ALUMINUM, INC', 'PO BOX 14165', 'GAINESVILLE', 'FL', 'ALACHUA', 'E'],
#  ['GATOR ALUMINUM AND SCREENS',
#   '85 LAKE DRIVE N.E. BHR',
#   'BUCKHEAD RIDGE',
#   'FL',
#   'GLADES',
#   'E'],
#  ['GATOR AMATEUR SOCIETY (GAS)',
#   '14850 E. LEVY ST.',
#   'WILLISTON',
#   'FL',
#   'MULTIPLE',
#   'A'],
#  ['GATOR APARTMENT GUIDE',
#   '1015 NE 5TH STREET',
#   'GAINESVILLE',
#   'FL',
#   'ALACHUA',
#   'E'],
#  ['GATOR APPLIANCE',
#   '5215 PARADE ST',
#   'TEMPLE TERRACE',
#   'FL',
#   'HILLSBOROUGH',
#   'E'],
#  ['GATOR APPLIANCE RECYCLING',
#   '4234 NE 17TH TERR.',
#   'GAINESVILLE',
#   'FL',
#   'ALACHUA',
#   'E'],
#  ['GATOR AQUATICS', '115 DOUGLAS AVENUE', 'DUNEDIN', 'FL', 'PINELLAS', 'I'],
#  ["GATOR AQUATIC'S", 'P.O. BOX 799', 'PARRISH', 'FL', 'MANATEE', 'E'],
#  ['GATOR AQUATICS CLEARING',
#   '2102 AUTMNLEAF  LANE',
#   'WINTER HAVEN',
#   'FL',
#   'POLK',
#   'E'],
#  ['GATOR AQUATICS LEARNING CENTER',
#   '6511 NW 54TH WAY',
#   'GAINESVILLE',
#   'FL',
#   'ALACHUA',
#   'A'],
#  ['GATOR ARMS & TACKLE BY DON',
#   '3204 SUNRISE BLVD',
#   'FT PIERCE',
#   'FL',
#   'ST. LUCIE',
#   'E'],
#  ['"GATOR ASPHALT"', '4323 NW 31 STREET', 'CAPE CORAL', 'FL', 'LEE', 'A'],
#  ['GATOR ASPHALT', '8343 HARDY STREET', 'PORT RICHEY', 'FL', 'MULTIPLE', 'A'],
#  ['GATOR ASPHALT', 'P.O. BOX 522', 'MICANOPY', 'FL', 'ALACHUA', 'E'],
#  ['GATOR ATHLETICS', 'PO BOX 1812', 'WEWAHITCHKA', 'FL', 'GULF', 'E'],
#  ['GATOR AUTO CUSTOMS',
#   '3500 NE WALDO ROAD',
#   'GAINESVILLE',
#   'FL',
#   'MULTIPLE',
#   'C'],
#  ['GATOR AUTO CUSTOMS',
#   '3500 NE WALDO ROAD',
#   'GAINESVILLE',
#   'FL',
#   'ALACHUA',
#   'A'],
#  ['GATOR AUTO CUSTOMS',
#   '3500 NE WALDO ROAD BLDG D',
#   'BRONSON',
#   'FL',
#   'ALACHUA',
#   'E'],
#  ['GATOR AUTO GLASS',
#   '7791 N.W. 178TH STREET',
#   'MIAMI',
#   'FL',
#   'MULTIPLE',
#   'C'],
#  ['GATOR AUTO GLASS',
#   '7791 NORTHWEST 178TH STREET',
#   'MIAMI',
#   'FL',
#   'MIAMI-DADE',
#   'E'],
#  ['GATOR AUTO GLASS',
#   '8087 MONETARY DR E-4',
#   'RIVIERA BEACH',
#   'FL',
#   'PALM BEACH',
#   'E'],
#  ['GATOR AUTO INSURANCE',
#   '2900 GLADES CIRCLE, STE 1050',
#   'WESTON',
#   'FL',
#   'PASCO',
#   'A'],
#  ['GATOR AUTO INSURANCE',
#   '8812 U.S.HWY 19',
#   'PORT RICHEY',
#   'FL',
#   'MULTIPLE',
#   'C'],
#  ['GATOR AUTO INSURANCE',
#   '9430 VIA SEGOVIA',
#   'NEW PORT RICHEY',
#   'FL',
#   'PASCO',
#   'E'],
#  ['GATOR AUTO INSURANCE',
#   'TPJ ENTERPRISES INC. GATOR AUTO INSURAN',
#   'CLEARWATER',
#   'FL',
#   'PINELLAS',
#   'A'],
#  ['GATOR AUTO INSURANCE AGENCY',
#   '1606 NORTH MAIN STREET',
#   'JACKSONVILLE',
#   'FL',
#   'DUVAL',
#   'E'],
#  ['GATOR AUTO INSURANCE AGENCY',
#   '1606 NORTH MAIN STREET',
#   'JACKSONVILLE',
#   'FL',
#   'DUVAL',
#   'A'],
#  ['GATOR AUTOMOTIVE', '15367 NW US HWY 441', 'ALACHUA', 'FL', 'ALACHUA', 'E'],
#  ['GATOR AUTOMOTIVE', '15367 NW US HWY 441', 'ALACHUA', 'FL', 'ALACHUA', 'A'],
#  ['GATOR AUTOMOTIVE ELECTRIC AND ACCESSORIES',
#   'PO BOX 5264',
#   'GAINESVILLE',
#   'FL',
#   'MULTIPLE',
#   'E'],
#  ['GATOR AUTOMOTIVE GROUP', 'P.O. BOX 699', 'MELBOURNE', 'FL', 'BREVARD', 'A'],
#  ['GATOR AUTOMOTIVE REPAIR',
#   '151 PRICE ROAD',
#   'HAWTHORNE',
#   'FL',
#   'PUTNAM',
#   'E'],
#  ['GATOR AUTO REPAIR SERVICE',
#   '400 N. CENTRAL AVE.',
#   'AVON PARK',
#   'FL',
#   'HIGHLANDS',
#   'A'],
#  ['GATOR AUTO SALES',
#   '7044 HOLLOWELL DRIVE',
#   'TAMPA',
#   'FL',
#   'HILLSBOROUGH',
#   'A'],
#  ['GATOR AUTO SALES', 'P O BOX 357747', 'GAINESVILLE', 'FL', 'ALACHUA', 'E'],
#  ['GATOR AUTO TOWING', '283 PEACH TREE', 'SPRING HILL', 'FL', 'HERNANDO', 'E'],
#  ['GATOR AVIATION',
#   '3627 N.W. 33RD TERRACE',
#   'GAINESVILLE',
#   'FL',
#   'MULTIPLE',
#   'E'],
#  ['GATORBACK INSTALLATIONS',
#   '6114 YUCCA DR.',
#   'FT.PIERCE',
#   'FL',
#   'ST. LUCIE',
#   'E'],
#  ['GATORBACK TRACTOR SERVICE',
#   '2190 LEMON AVE',
#   'ENGLEWOOD',
#   'FL',
#   'SARASOTA',
#   'E'],
#  ['GATORBACK TRANSPORTING',
#   '4631 KEYSVILLE ROAD EAST',
#   'LITHIA',
#   'FL',
#   'HILLSBOROUGH',
#   'E'],
#  ['GATOR BAIL BONDS',
#   '103301 OVERSEAS HIGHWAY',
#   'KEY LARGO',
#   'FL',
#   'MULTIPLE',
#   'E'],
#  ['GATOR BAIT',
#   'GATOR BAIT ATTN: SERGIO COLE',
#   'SHELBYVILLE',
#   'KY',
#   'ALACHUA',
#   'A'],
#  ['GATORBAIT CAFE',
#   '17595 SOUTH TAMIAMI TRAIL',
#   'FORT MYERS',
#   'FL',
#   'COLLIER',
#   'A'],
#  ['GATOR BAIT DETAILING',
#   '3310 SE 22ND AVENUE',
#   'GAINESVILLE',
#   'FL',
#   'ALACHUA',
#   'E'],
#  ['GATOR BAIT FOODS, LLC',
#   '2028 E STATE RD 60',
#   'VALRICO',
#   'FL',
#   'HILLSBOROUGH',
#   'E'],
#  ['GATOR BAIT GOLF BALLS',
#   '1383 MISSION SAN CARLOS DRIVE',
#   'AMELIA ISLAND',
#   'FL',
#   'NASSAU',
#   'E'],
#  ['GATOR BAIT-GOLF BALLS',
#   '9624 CRESCENT GARDEN DR.',
#   'NAPLES',
#   'FL',
#   'COLLIER',
#   'E'],
#  ['GATOR BAIT GOLF BALLS',
#   'P.O. BOX 8015',
#   'AMELIA ISLAND',
#   'FL',
#   'NASSAU',
#   'E'],
#  ['GATOR BAIT HOMEMADE ALL NATURAL PRODUCTS',
#   '1080 RORDAN AVENUE',
#   'NAPLES',
#   'FL',
#   'COLLIER',
#   'E'],
#  ['GATORBAITMANIA.COM',
#   'P.O. BOX 297144',
#   'PEMBROKE PINES',
#   'FL',
#   'MULTIPLE',
#   'E'],
#  ['GATOR BAIT MOBILE DETAILING BY MOTE ENTERPRISES',
#   '2581 SUNRISE RIDGE LANE',
#   'JACKSONVILLE',
#   'FL',
#   'MULTIPLE',
#   'E'],
#  ['GATOR BAIT PUB',
#   '17070 STATE RD. 80 WEST',
#   'CLEWISTON',
#   'FL',
#   'HENDRY',
#   'E'],
#  ['GATORBAITS COMPLETE LAWN CARE',
#   '5040 SW 26TH AVE',
#   'FORT LAUDERDALE',
#   'FL',
#   'BROWARD',
#   'E'],
#  ['GATOR BAKED',
#   '270 WAYMONT CT. SUITE 120',
#   'LAKE MARY',
#   'FL',
#   'ALACHUA',
#   'A'],
#  ['GATOR BALLS',
#   '374 SW CHERRY HILL RD',
#   'PORT ST. LUCIE',
#   'FL',
#   'MULTIPLE',
#   'E'],
#  ['GATORBANNER.COM', '2444 NE 1ST BLVD', 'GAINESVILLE', 'FL', 'ALACHUA', 'E'],
#  ['THE GATOR BAR', '109 OLD BUBBLY RD', 'PIERSON', 'FL', 'MULTIPLE', 'A'],
#  ['THE GATOR BAR',
#   '5115 NORTH HWY. 17',
#   'DELEON SPRINGS',
#   'FL',
#   'VOLUSIA',
#   'A'],
#  ['GATOR BAR', '5125 US HIGHWAY 17 N', 'DELEON SPRINGS', 'FL', 'VOLUSIA', 'A'],
#  ['GATOR BARBER AND STYLE SHOP',
#   '3452 W. UNIVERSITY AVENUE',
#   'GAINESVILLE',
#   'FL',
#   'ALACHUA',
#   'E'],
#  ['GATOR BARBER & STYLE SHOP',
#   '3452 WEST UNIVERSITY AVE.',
#   'GAINESVILLE',
#   'FL',
#   'ALACHUA',
#   'A'],
#  ['GATOR BARBER & STYLE SHOP',
#   '6855 W HWY 40 STE. D',
#   'OCALA',
#   'FL',
#   'MARION',
#   'A'],
#  ['GATOR BARBER & STYLE SHOP',
#   '6855 W. HIGHWAY 40 STE. D',
#   'OCALA',
#   'FL',
#   'MARION',
#   'E'],
#  ['GATOR BASIC COMPUTER SERVICES',
#   'P. O. BOX 823',
#   'PORT RICHEY',
#   'FL',
#   'MULTIPLE',
#   'A'],
#  ['GATOR BAY BAR & GRILL', 'PO BOX 895081', 'LEESBURG', 'FL', 'LAKE', 'E'],
#  ['GATOR BAY DELI', '3407 20TH AVE DR W', 'BRADENTON', 'FL', 'MANATEE', 'E'],
#  ['GATOR BAY JANITORAL',
#   '3610 MAGNOLIA RIDGE CIRCLE',
#   'PALM HARBOR',
#   'FL',
#   'PINELLAS',
#   'E'],
#  ['GATOR BAY JANITORIAL',
#   '12510 BAY BRANCH CT.',
#   'TAMPA',
#   'FL',
#   'MULTIPLE',
#   'A'],
#  ['GATOR BAY LANDSCAPING & LAWN MAINTENANCE',
#   '3407 20TH AVE DR. W.',
#   'BRADENTON',
#   'FL',
#   'MANATEE',
#   'E'],
#  ['GATOR BAY LOGGING', '2648 SUN LAKE RD', 'BONIFAY', 'FL', 'WASHINGTON', 'E'],
#  ['GATOR BAY MARINA', 'PO BOX 895081', 'LEESBURG', 'FL', 'LAKE', 'E'],
#  ['GATOR BAY SOD', 'PO BOX 331443', 'ATLANTIC BEACH', 'FL', 'FLAGLER', 'A'],
#  ['GATOR BAY TRADING CO.',
#   '710 SW 16TH AVENUE # 108',
#   'GAINESVILLE',
#   'FL',
#   'ALACHUA',
#   'E'],
#  ['GATOR BAY TRANSPORT', '97 JODI AVENUE', 'LEESBURG', 'FL', 'LAKE', 'E'],
#  ['GATOR BAZAAR AND THRIFT STORE',
#   '6105 SW 10 PL APT A',
#   'GAINESVILLE',
#   'FL',
#   'ALACHUA',
#   'A'],
#  ['GATOR-BILT INSTALLATIONS',
#   '12746 WOODBURY OAKS DRIVE',
#   'ORLANDO',
#   'FL',
#   'ORANGE',
#   'A'],
#  ['GATOR BITE CAFE', '1404 N CHERRY POP DR', 'HERNANDO', 'FL', 'CITRUS', 'E'],
#  ['GATOR BITES', '130 CHURCH STREET', 'VALRICO', 'FL', 'HILLSBOROUGH', 'A'],
#  ['GATOR BITES', '2856 FALLING TREE CIRCLE', 'ORLANDO', 'FL', 'OSCEOLA', 'E'],
#  ['GATOR BITES', '315 WGTO TOWER RD', 'LAKE ALFRED', 'FL', 'POLK', 'E'],
#  ['GATOR BITES', 'P.O. BOX 851', 'SEFFNER', 'FL', 'HILLSBOROUGH', 'C'],
#  ['GATOR BITES LEATHER',
#   '2826 DUNCAN TREE CIRCLE',
#   'VALRICO',
#   'FL',
#   'HILLSBOROUGH',
#   'E'],
#  ['GATORBITES TAIL & ALE',
#   '20351 SUMMERLIN RD',
#   'FORT MYERS',
#   'FL',
#   'LEE',
#   'A'],
#  ['GATOR BITES TAIL & ALE', '580 BIRDSONG PLACE', 'SANIBEL', 'FL', 'LEE', 'E'],
#  ['GATOR BLINDS', '1631 ROCK SPRINGS RD.', 'APOPKA', 'FL', 'MULTIPLE', 'C'],
#  ['GATOR BLINDS', '490 NORTH STREET', 'LONGWOOD', 'FL', 'MULTIPLE', 'A'],
#  ['GATOR BLINDS & SHUTTERS',
#   '1871 N.E. 23RD ST',
#   'OCALA',
#   'FL',
#   'MULTIPLE',
#   'E'],
#  ['GATOR BLINDS & SHUTTERS', '1871 NE 23RD ST', 'OCALA', 'FL', 'MARION', 'A'],
#  ['GATOR BLINK', '1109 W UNIVERSITY AVE', 'GAINESVILLE', 'FL', 'ALACHUA', 'E'],
#  ['GATORBLOO',
#   '117 WEATHERSFIELD AVE',
#   'ALTAMONTE SPRINGS',
#   'FL',
#   'MULTIPLE',
#   'E'],
#  ['GATOR BLUE CLEANING SERVICES',
#   '2263 NE 4TH AVE',
#   'GAINESVILLE',
#   'FL',
#   'MULTIPLE',
#   'C'],
#  ['GATORBLUES', '1974 RED BUD CIRCLE', 'PALM BAY', 'FL', 'MULTIPLE', 'E'],
#  ['GATOR BLUES PRODUCTIONS',
#   '2000 4TH AVENUE N.',
#   'ST. PETERSBURG',
#   'FL',
#   'PINELLAS',
#   'E'],
#  ['GATOR BLUES PUBLISHING',
#   '2000 4TH AVENUE NORTH',
#   'ST PETERSBURG',
#   'FL',
#   'PINELLAS',
#   'E'],
#  ['GATOR BOARD SHOP',
#   '1059 HAWTHORNE DRIVE',
#   'SEBRING',
#   'FL',
#   'HIGHLANDS',
#   'E'],
#  ['GATOR BOAT WORKS',
#   '701 J C CENTER COURT STE 11',
#   'PORT CHARLOTTE',
#   'FL',
#   'CHARLOTTE',
#   'A'],
#  ['GATOR BOBS CRACKER GIFT SHOP',
#   '201 FRONT STREET',
#   'KEY WEST',
#   'FL',
#   'ST. JOHNS',
#   'E'],
#  ["GATOR BOB'S CRACKER GIFT SHOP",
#   '201 FRONT STREET',
#   'KEY WEST',
#   'FL',
#   'ST. JOHNS',
#   'A'],
#  ["GATOR BOB'S CRACKER TRADING POST",
#   '167 SAN MARCO AVENUE',
#   'ST. AUGUSTINE',
#   'FL',
#   'ST. JOHNS',
#   'A'],
#  ['GATORBONE STUDIOS',
#   'POST OFFICE BOX 1653',
#   'KEYSTONE HEIGHTS',
#   'FL',
#   'CLAY',
#   'A'],
#  ['GATOR BOUNCE LLC',
#   '6222 DAINTY BESS CT',
#   "LAND O'LAKES",
#   'FL',
#   'PASCO',
#   'E'],
#  ['GATOR BOYS PAINTING',
#   '16134 MUIRFIELD DRIVE',
#   'ODESSA',
#   'FL',
#   'HILLSBOROUGH',
#   'E'],
#  ['GATORBRADE', '5530 COMMERCIAL BLVD', 'WINTER HAVEN', 'FL', 'POLK', 'E'],
#  ['GATOR BRIDE VIDEOGRAPHY',
#   '25709 NW 169TH LANE',
#   'HIGH SPRINGS',
#   'FL',
#   'ALACHUA',
#   'A'],
#  ['GATOR BRITE TEETH WHITENING',
#   '101 N. MAIN STREET',
#   'GAINESVILLE',
#   'FL',
#   'ALACHUA',
#   'E'],
#  ['GATORBUC  ENTERPRISES',
#   '123 NE 132ND TERRACE',
#   'GAINESVILLE',
#   'FL',
#   'ALACHUA',
#   'E'],
#  ['GATOR-BUCKS, INC.',
#   '531 N. ST. RD 7',
#   'ROYAL PALM BEACH',
#   'FL',
#   'PALM BEACH',
#   'E'],
#  ['GATORBUILT', '2601 SW 79TH AVE', 'DAVIE', 'FL', 'MULTIPLE', 'E'],
#  ['GATOR BUILT', 'PO BOX 740737', 'ORANGE CITY', 'FL', 'PALM BEACH', 'E'],
#  ['GATORBUSTERS', '11451 SCHAEFER LN.', 'LAKE WALES', 'FL', 'POLK', 'A'],
#  ['GATOR BUS TOURS',
#   '8815 CONROY-WINDERMERE RD. #308',
#   'ORLANDO',
#   'FL',
#   'MULTIPLE',
#   'A'],
#  ['GATORBUYBACK.COM',
#   '4000 S.W. 23RD ST. APT 6-205',
#   'GAINESVILLE',
#   'FL',
#   'ALACHUA',
#   'E'],
#  ['GATOR B WELDING', '1631 SW 16TH ST', 'OKEECHOBEE', 'FL', 'OKEECHOBEE', 'E'],
#  ['GATOR-BYTE COMPUTERS',
#   '921 NUTMEG AVE',
#   'NICEVILLE',
#   'FL',
#   'OKALOOSA',
#   'E'],
#  ['GATORBYTE COMPUTER SYSTEMS',
#   '2370 S.W. ARCHER RD. #75',
#   'GAINESVILLE',
#   'FL',
#   'ALACHUA',
#   'E'],
#  ['GATOR BYTE COMPUTING',
#   '3712 HOWELL BRANCH ROAD',
#   'WINTER PARK',
#   'FL',
#   'SEMINOLE',
#   'E'],
#  ['GATOR BYTE COMPUTING',
#   '5610 NW 33RD STREET',
#   'GAINESVILLE',
#   'FL',
#   'ALACHUA',
#   'E'],
#  ['GATORBYTE COMPUTING',
#   '9136 SW 17TH AVENUE',
#   'GAINESVILLE',
#   'FL',
#   'ALACHUA',
#   'E'],
#  ['GATOR BYTES', 'PO BOX 243', 'WELAKA', 'FL', 'PUTNAM', 'E'],
#  ['GATOR-BYTES COMPUTER',
#   '3539 SW 19TH AVENUE,  #A-2',
#   'GAINESVILLE',
#   'FL',
#   'ALACHUA',
#   'E'],
#  ['GATOR BYTES COMPUTERS', 'PO BOX 50874', 'FORT MYERS', 'FL', 'LEE', 'E'],
#  ['GATOR CAB', '1265 PINE AVENUE', 'ORLANDO', 'FL', 'ORANGE', 'A'],
#  ['GATOR CAB', '212 S.W. 4TH AVE', 'GAINESVILLE', 'FL', 'ALACHUA', 'E'],
#  ['GATOR CAB COMPANY OF GAINESVILLE',
#   '3801 NW 6TH STREET',
#   'GAINESVILLE',
#   'FL',
#   'ALACHUA',
#   'E'],
#  ['GATORCADE', '4618 NW 43 PLACE', 'GAINESVILLE', 'FL', 'ALACHUA', 'A'],
#  ['GATORCADE', '4618 NW 43RD PLACE', 'GAINESVILLE', 'FL', 'ALACHUA', 'A'],
#  ['GATOR CAFE',
#   '1212 NORTH MAIN  STREET',
#   'GAINESVILLE',
#   'FL',
#   'ALACHUA',
#   'E'],
#  ['GATOR CAFE', '1810 N.W. 23RD BLVD.', 'GAINESVILLE', 'FL', 'ALACHUA', 'E'],
#  ['GATOR CAFE', '661 HWY 17 SOUTH', 'SAN MATEO', 'FL', 'PUTNAM', 'A'],
#  ['GATOR CAPITAL, LLC',
#   '1225 WEST BEAVER STREET',
#   'JACKSONVILLE',
#   'FL',
#   'MULTIPLE',
#   'E'],
#  ['GATOR CAR AUDIO & PERFORMANCE',
#   '3402 NE 2ND ST.',
#   'GAINESVILLE',
#   'FL',
#   'ALACHUA',
#   'A'],
#  ['GATOR CAR CARE', '340 STORY RD.', 'OCOEE', 'FL', 'ORANGE', 'E'],
#  ['GATORCARE', '1329 SW 16TH STREET', 'GAINESVILLE', 'FL', 'ALACHUA', 'A'],
#  ['GATOR CARE CARE', '4511 DEL PRADO BLVD.', 'CAPE CORAL', 'FL', 'LEE', 'A'],
#  ['GATOR CARPET CARE',
#   '3810 FRIARS COVE ROAD',
#   'SAINT CLOUD',
#   'FL',
#   'OSCEOLA',
#   'E'],
#  ['GATOR CARPET & UPHOLSTERY CLEANING',
#   '280 - 13TH ST SW',
#   'NAPLES',
#   'FL',
#   'COLLIER',
#   'E'],
#  ['GATOR CAR RENTAL',
#   '250 174 STR., UNIT 1120',
#   'SUNNY ISLES BEACH',
#   'FL',
#   'MIAMI-DADE',
#   'A'],
#  ['GATORCARSONLINE.COM',
#   '2921 NW 75TH TERR',
#   'GAINESVILLE',
#   'FL',
#   'ALACHUA',
#   'E'],
#  ['GATOR CAR WASH', '11350 MAHOGANY RUN', 'FORT MYERS', 'FL', 'LEE', 'E'],
#  ['GATOR CAR WASH', '2910 LEE ROAD', 'LEHIGH ACRES', 'FL', 'LEE', 'E'],
#  ['GATOR - CHEM POOLS', '6109 COLE DR', 'TAMPA', 'FL', 'HILLSBOROUGH', 'C'],
#  ['GATOR-CHEM POOLS', '6109 COLE DR.', 'TAMPA', 'FL', 'HILLSBOROUGH', 'A'],
#  ['GATOR CHEVROLET', '208 HATLEY STREET SE', 'JASPER', 'FL', 'HAMILTON', 'A'],
#  ['GATOR CHEVRON', '4410 NW CR 326', 'OCALA', 'FL', 'MULTIPLE', 'E'],
#  ['GATOR CHEVRON', '4410 NW CR 326', 'OCALA', 'FL', 'MARION', 'E'],
#  ['GATOR CHEVRON', '4410 NW HWY 326', 'OCALA', 'FL', 'MARION', 'E'],
#  ['GATOR CHIMNEY', '1303 BELVEDERE AVE', 'JACKSONVILLE', 'FL', 'ALACHUA', 'A'],
#  ['THE GATOR CHOMP', 'PO BOX 952308', 'LAKE MARY', 'FL', 'SEMINOLE', 'E'],
#  ['GATORCHOMP SERVICES',
#   'PO BOX 140045',
#   'GAINESVILLLE',
#   'FL',
#   'ALACHUA',
#   'E'],
#  ['GATOR CHOPPERS',
#   '12016 RUNNING FOX CIR',
#   'RIVERVIEW',
#   'FL',
#   'HILLSBOROUGH',
#   'E'],
#  ['GATOR CHRYSLER DODGE JEEP',
#   'P.O. BOX  699',
#   'MELBOURNE',
#   'FL',
#   'BREVARD',
#   'A'],
#  ['GATOR CHRYSLER SUZUKI',
#   '300 E NASA BLVD.',
#   'MELBOURNE',
#   'FL',
#   'BREVARD',
#   'E'],
#  ['GATOR CINEMAS',
#   '6741 WEST NEWBERRY RD.',
#   'GAINESVILLE',
#   'FL',
#   'ALACHUA',
#   'E'],
#  ['GATOR CINEMAS', '823 5TH AVE', 'ANTIGO', 'WI', 'ALACHUA', 'E'],
#  ['GATOR CINEMAS', 'P.O. BOX 532', 'ANTIGO', 'WI', 'ALACHUA', 'E'],
#  ['GATOR CIRCLE LAWNCARE',
#   '3925 E. GATOR CIRCLE',
#   'CAPE CORAL',
#   'FL',
#   'LEE',
#   'E'],
#  ['GATOR CITRUS REMOVAL', '4162 SE CR 760', 'ARCADIA', 'FL', 'DESOTO', 'E'],
#  ['GATOR CITY',
#   '1728 W. UNIVERSITY AVE.',
#   'GAINESVILLE',
#   'FL',
#   'ALACHUA',
#   'E'],
#  ['GATOR CITY', 'PO BOX 14077', 'GAINESVILLE', 'FL', 'ALACHUA', 'A'],
#  ['GATOR CITY BILLIARDS',
#   '1728 W. UNIVERSITY AVENUE',
#   'GAINESVILLE',
#   'FL',
#   'ALACHUA',
#   'E'],
#  ['GATOR CITY CITGO',
#   '3310 SW 35TH BLVD',
#   'GAINESVILLE',
#   'FL',
#   'ALACHUA',
#   'E'],
#  ['GATOR CITY HOME REPAIR & PAINTING',
#   '8737 COCOA AVE',
#   'JACKSONVILLE',
#   'FL',
#   'DUVAL',
#   'E'],
#  ['GATOR CITY SALOON',
#   '1728 W. UNIVERSITY AVENUE',
#   'GAINESVILLE',
#   'FL',
#   'ALACHUA',
#   'E'],
#  ['GATOR CITY SEAFOOD',
#   '2819 FITZGERALD ST',
#   'JACKSONVILLE',
#   'FL',
#   'DUVAL',
#   'E'],
#  ['GATOR CITY SPORTS GRILLE',
#   '10827 SW 17TH LANE',
#   'GAINESVILLE',
#   'FL',
#   'ALACHUA',
#   'A'],
#  ['GATOR CITY SPORTS GRILLE',
#   '1728 W. UNIVERSITY AVENUE',
#   'GAINESVILLE',
#   'FL',
#   'ALACHUA',
#   'E'],
#  ['GATOR CITY STORAGE', 'P.O. BOX 28586', 'JACKSONVILLE', 'FL', 'DUVAL', 'A'],
#  ['GATOR CITY TAXI',
#   '1635 MEATHE DRIVE',
#   'WEST PALM BEACH',
#   'FL',
#   'PALM BEACH',
#   'E'],
#  ['GATOR CITY TAXI',
#   '5320 SPRINGFIELD BLVD',
#   'JACKSONVILLE',
#   'FL',
#   'MULTIPLE',
#   'E'],
#  ['GATOR CITY TAXI',
#   '5320 SPRINGFIELD BLVD.',
#   'JACKSONVILLE',
#   'FL',
#   'DUVAL',
#   'E'],
#  ['GATOR CITY TAXI',
#   '720 E. BUTTERFIELD ROAD, SUITE 300',
#   'LOMBARD',
#   'IL',
#   'DUVAL',
#   'A'],
#  ['GATOR CITY TAXI & SHUTTLE',
#   '5320 SPRINGFIELD BLVD',
#   'JACKSONVILLE',
#   'FL',
#   'DUVAL',
#   'E'],
#  ['GATOR CITY TAXI & SHUTTLE',
#   '5320 SPRINGFIELD BLVD',
#   'JACKSONVILLE',
#   'FL',
#   'MULTIPLE',
#   'E'],
#  ['GATOR CLAIMS PROCESSING',
#   '13310 NW 142 TER',
#   'ALACHUA',
#   'FL',
#   'ALACHUA',
#   'E'],
#  ['GATOR CLASSIC',
#   '2632 WEST STATE ROAD 434 #100',
#   'LONGWOOD',
#   'FL',
#   'ORANGE',
#   'E'],
#  ['GATOR CLEAN', '1631 ROCK SPRINGS ROAD', 'APOPKA', 'FL', 'MULTIPLE', 'E'],
#  ['GATOR CLEAN', '427 SPLIT OAK CT', 'EUSTIS', 'FL', 'MULTIPLE', 'A'],
#  ['GATOR CLEAN', '7330 GROVE RD', 'BROOKSVILLE', 'FL', 'HERNANDO', 'C'],
#  ['GATOR CLEAN', '8094 MORELLI AVE.', 'BROOKSVILLE', 'FL', 'HERNANDO', 'C'],
#  ['GATOR-CLEAN', 'P.O. BOX 173', 'PALATKA', 'FL', 'PUTNAM', 'E'],
#  ['GATOR CLEAN 2000',
#   '9765 SOUTHBROOK DR.',
#   'JACKSONVILLE',
#   'FL',
#   'DUVAL',
#   'E'],
#  ['GATOR CLEANERS AND LAUNDRY',
#   '2701 EUNICE AVE',
#   'ORLANDO',
#   'FL',
#   'MULTIPLE',
#   'E'],
#  ['GATOR CLEANING', '6633 RIGGER RD', 'LANTANA', 'FL', 'PALM BEACH', 'E'],
#  ['GATOR CLEANING', 'PO BOX 60', 'POMONA PARK', 'FL', 'PUTNAM', 'E'],
#  ['GATOR CLEANING ACTION',
#   '10215 RIVA RIDGE TRAIL',
#   'ORLANDO',
#   'FL',
#   'MULTIPLE',
#   'A'],
#  ['GATOR CLEANING BUSINESS',
#   '605 NE 53RD AVE A 8B',
#   'GAINESVILLE',
#   'FL',
#   'ALACHUA',
#   'E'],
#  ['GATOR CLEANING & RESTORATION',
#   'PO BOX 390357',
#   'DELTONA',
#   'FL',
#   'MULTIPLE',
#   'E'],
#  ['GATOR CLEANING SERVICE',
#   '1020-C NW 23RD AVE',
#   'GAINESVILLE',
#   'FL',
#   'MULTIPLE',
#   'E'],
#  ['"GATOR CLEANING SERVICE"',
#   '4251 SW 13TH SUITE 2-A',
#   'GAINESVILLE',
#   'FL',
#   'ALACHUA',
#   'E'],
#  ['GATOR CLEANING SERVICE',
#   '5809 TROUT RIVER BLVD. LOT# 56',
#   'JACKSONVILLE',
#   'FL',
#   'MULTIPLE',
#   'E'],
#  ['GATOR CLEANING SERVICES',
#   'PO BOX 597',
#   'TARPON SPRINGS',
#   'FL',
#   'MULTIPLE',
#   'E'],
#  ['GATOR CLEANING SOLUTIONS INC',
#   '14945 PRINCEWOOD LANE',
#   'LAND O LAKES',
#   'FL',
#   'MULTIPLE',
#   'E'],
#  ['GATOR CLEANING SOLUTIONS INC',
#   '14945 PRINCEWOOD LANE',
#   'LAND O LAKES',
#   'FL',
#   'PASCO',
#   'E'],
#  ['GATOR CLIPS', '1618 NW 19TH LANE', 'GAINESVILLE', 'FL', 'ALACHUA', 'E'],
#  ['THE GATOR CLUB', '1490 MAIN STREET', 'SARASOTA', 'FL', 'SARASOTA', 'E'],
#  ['THE GATOR CLUB', '1490 MAIN STREET', 'SARASOTA', 'FL', 'SARASOTA', 'A'],
#  ['THE GATOR CLUB',
#   '3816 W. LINEBAUGH AVENUE',
#   'TAMPA',
#   'FL',
#   'HILLSBOROUGH',
#   'E'],
#  ['GATORCNA', '1029 NW 23RD AVE', 'GAINESVILLE', 'FL', 'MULTIPLE', 'A'],
#  ['GATORCO', '125 THE LN', 'LAKE PLACID', 'FL', 'HIGHLANDS', 'E'],
#  ['GATOR COATING', '1395 WEST', 'HIALEAH', 'FL', 'MULTIPLE', 'A'],
#  ['GATOR COATINGS',
#   '4394 S SALFORD BLVD',
#   'NORTH PORT',
#   'FL',
#   'CHARLOTTE',
#   'E'],
#  ['GATOR COAT POWDER COATING',
#   '30531 SORRENTO LN',
#   'SAN ANTONIO',
#   'FL',
#   'PASCO',
#   'E'],
#  ['GATOR COFFEE', '2315 NW 107TH AVE', 'DORAL', 'FL', 'MIAMI-DADE', 'A'],
#  ['GATOR COIN SHOP', '2857 CHARMONT DR', 'APOPKA', 'FL', 'SEMINOLE', 'E'],
#  ['GATOR-CO LAWN MAINTENANCE AND PROPERTY MANAGEMENT',
#   '4545 GARLAND BRANCH RD',
#   'DOVER',
#   'FL',
#   'HILLSBOROUGH',
#   'A'],
#  ['GATOR COMMUNICATIONS',
#   '1850 PROVIDENCE LAKES BLVD.',
#   'BRANDON',
#   'FL',
#   'HILLSBOROUGH',
#   'E'],
#  ['GATOR COMMUNICATIONS',
#   '4316 FERRARRA STREET',
#   'JACKSONVILLE',
#   'FL',
#   'DUVAL',
#   'E'],
#  ['GATOR COMMUNICATIONS',
#   '4609 N.W. 6TH STREET',
#   'GAINESVILLE',
#   'FL',
#   'ALACHUA',
#   'E'],
#  ['GATOR COMMUNICATION SYSTEMS',
#   '4511 JESSI LANE',
#   'LITHIA',
#   'FL',
#   'HILLSBOROUGH',
#   'E'],
#  ['GATOR COMPLETE LAWN CARE',
#   '6812 GILDA CT.',
#   'KEYSTONE HEIGHTS',
#   'FL',
#   'MULTIPLE',
#   'C'],
#  ['GATOR COMPLETE LAWN CARE',
#   '6812 GILDA CT.',
#   'KEYSTONE HEIGHTS',
#   'FL',
#   'MULTIPLE',
#   'A'],
#  ['GATOR COMPRESSOR INC.',
#   '5703 BASSETT PLACE',
#   'SANFORD',
#   'FL',
#   'SEMINOLE',
#   'E'],
#  ['GATORCOMPS',
#   '205 S.W. 75TH ST., SUITE 6A',
#   'GAINSVILLE',
#   'FL',
#   'ALACHUA',
#   'E'],
#  ['GATOR COMPUTERS',
#   '1219 WEST UNIVERSITY AVENUE',
#   'GAINESVILLE',
#   'FL',
#   'ALACHUA',
#   'E'],
#  ['GATOR COMPUTERS',
#   '1219 WEST UNIVERSITY AVENUE',
#   'GAINESVILLE',
#   'FL',
#   'ALACHUA',
#   'E'],
#  ['GATOR COMPUTERS',
#   '1313 HILLSIDE DR.',
#   'TARPON SPRINGS',
#   'FL',
#   'MULTIPLE',
#   'E'],
#  ['GATOR COMPUTER SERVICES',
#   '260 WEBER BLVD.,SOUTH',
#   'NAPLES',
#   'FL',
#   'COLLIER',
#   'E'],
#  ['GATOR COMPUTER SOLUTIONS',
#   '3921 SW 34 ST., APT 310',
#   'GAINESVILLE',
#   'FL',
#   'BROWARD',
#   'E'],
#  ['GATOR COMPUTER SOLUTIONS',
#   '3921 SW 34ST',
#   'GAINESVILLE',
#   'FL',
#   'MULTIPLE',
#   'E'],
#  ['GATOR COMPUTING CONSULTANT',
#   '7934 ELWOOD DR',
#   'LAKE WORTH',
#   'FL',
#   'PALM BEACH',
#   'E'],
#  ['GATORCON!', '231 ANDOVER I', 'WEST PALM BEACH', 'FL', 'MULTIPLE', 'A'],
#  ['GATOR CONCEPTS', '16809 CAMILLE ST', 'HUDSON', 'FL', 'MULTIPLE', 'E'],
#  ['GATOR CONCRETE COATINGS',
#   '7910 SW 202 ND ST.',
#   'ARCHER',
#   'FL',
#   'ALACHUA',
#   'E'],
#  ['GATOR CONCRETE & MASONRY CONSTRUCTION LLC',
#   '800 NE 4TH AVE',
#   'MULBERRY',
#   'FL',
#   'POLK',
#   'V'],
#  ['GATOR CONCRETE & TOPPING',
#   '27451 MILLER RD',
#   'DADE CITY',
#   'FL',
#   'PASCO',
#   'E'],
#  ['GATOR CONNECTION', '100 C. HWY 27', 'MINNEOLA', 'FL', 'LAKE', 'E'],
#  ['GATOR CONNECTION', '179 N HWY 27', 'CLERMONT', 'FL', 'LAKE', 'C'],
#  ['GATOR CONNECTION', '179 N HWY 27 SUITE D', 'CLERMONT', 'FL', 'LAKE', 'C'],
#  ['GATOR CONSTRUCTION', '2401 STANTON ST', 'AUBURNDALE', 'FL', 'POLK', 'E'],
#  ['GATOR CONSTRUCTION OF ALASKA',
#   '3200 PARK STREET',
#   'PALATKA',
#   'FL',
#   'PUTNAM',
#   'E'],
#  ['GATOR CONSTRUCTION CLEANING AND BREVARD JANITORIAL SERVICES',
#   '2220 MERION DRIVE',
#   'MELBOURNE',
#   'FL',
#   'BREVARD',
#   'C'],
#  ['GATOR CONSTRUCTION CONSULTANTS',
#   '302 MORNING GLORY DR.',
#   'LAKE MARY',
#   'FL',
#   'SEMINOLE',
#   'E'],
#  ['GATOR CONSTRUCTION AND CONSULTING',
#   '5363 SHORELINE CIRCLE',
#   'SANFORD',
#   'FL',
#   'SEMINOLE',
#   'A'],
#  ['GATOR CONSTRUCTION OF ESTERO',
#   'PO BOX 982',
#   'ESTERO',
#   'FL',
#   'MULTIPLE',
#   'E'],
#  ['GATOR CONSTRUCTION SERVICES',
#   '1315 SE 3TH ST',
#   'CAPE CORAL',
#   'FL',
#   'LEE',
#   'E'],
#  ['GATOR CONSTRUCTION SERVICES',
#   'PO BOX 982',
#   'ESTERO',
#   'FL',
#   'MULTIPLE',
#   'E'],
#  ['GATOR CONSTRUCTION OF SOUTH WEST FLA',
#   '21312 BERKSHIRE AVE.',
#   'PORT CHARLOTTE',
#   'FL',
#   'CHARLOTTE',
#   'C'],
#  ['GATOR CONSTRUCTION OF SOUTHWEST FLA',
#   '23520 WALDEN CENTER DRIVE',
#   'BONITA SPRINGS',
#   'FL',
#   'CHARLOTTE',
#   'E'],
#  ['GATOR CONSTRUCTION OF SW FLORIDA',
#   '306 ORCHARD RIDGE DRIVE',
#   'MICHIGAN',
#   'MI',
#   'CHARLOTTE',
#   'E'],
#  ['GATOR CONSULTANT INT, INC',
#   '1222 NE 4TH AVENUE',
#   'FORT LAUDERDALE',
#   'FL',
#   'BROWARD',
#   'E'],
#  ['GATOR CONSULTING ASSOCIATES',
#   '10000 SW 52 AVE',
#   'GAINESVILLE',
#   'FL',
#   'ALACHUA',
#   'E'],
#  ['GATOR CONSULTING SERVICES',
#   '14566 CHERRY LAKE DR WEST',
#   'JACKSONVILLE',
#   'FL',
#   'DUVAL',
#   'A'],
#  ['GATOR CONVENIENCE',
#   '3550 SW 34TH STREET',
#   'GAINESVILLE',
#   'FL',
#   'ALACHUA',
#   'A'],
#  ['GATOR CONVENIENCE',
#   '3550 SW 34TH STREET, #H',
#   'GAINESVILLE',
#   'FL',
#   'ALACHUA',
#   'A'],
#  ['GATOR CONVENIENCE',
#   '3550-H S.W. 34TH ST.',
#   'GAINESVILLE',
#   'FL',
#   'ALACHUA',
#   'E'],
#  ['GATOR CONVENIENCE AND FOOD MART',
#   '3550 SW 34TH ST',
#   'GAINESVILLE',
#   'FL',
#   'ALACHUA',
#   'A'],
#  ['GATOR CORE COMAPNY',
#   '9983 NW 24TH ST',
#   'CORAL SPRINGS',
#   'FL',
#   'BROWARD',
#   'E'],
#  ['GATOR CORE & RECYCLING',
#   'P.O. BOX 574',
#   'RIVERVIEW',
#   'FL',
#   'HILLSBOROUGH',
#   'E'],
#  ['GATOR COUNTRY', '5048 BRYWALL CIRCLE', 'SARASOTA', 'FL', 'SARASOTA', 'E'],
#  ['GATOR COUNTRY', '900 PARISH STREET', 'PITTSBURGH', 'PA', 'LEE', 'A'],
#  ['GATOR COUNTRY 101.9 FM/WWGR',
#   '10915 K-NINE DR',
#   'BONITA SPRINGS',
#   'FL',
#   'LEE',
#   'E'],
#  ['GATOR COUNTRY AIRBOAT TOURS',
#   '1400 GRAPE HAMMOCK RD',
#   'LAKE WALES',
#   'FL',
#   'POLK',
#   'E'],
#  ['GATOR COUNTRY AUTO SALES', 'PO BOX 850', 'CHIEFLAND', 'FL', 'LEVY', 'C'],
#  ['GATOR COUNTRY AUTO SALES', 'PO BOX 850', 'CHIEFLAND', 'FL', 'LEVY', 'A'],
#  ['GATOR COUNTRY CANE CORSOS',
#   '920 S STATE RD 415',
#   'NEW SMYRNA',
#   'FL',
#   'VOLUSIA',
#   'E'],
#  ['GATOR COUNTRY CARDS & COMICS',
#   '3739 W. UNIVERSITY AVENUE',
#   'GAINESVILLE',
#   'FL',
#   'ALACHUA',
#   'C'],
#  ['GATOR COUNTRY COMPUTERS',
#   'PO BOX 172',
#   'INTERLACHEN FL',
#   'FL',
#   'PUTNAM',
#   'E'],
#  ['GATOR COUNTRY LAWN CARE',
#   '1575 WHOOPING DR.',
#   'GROVELAND',
#   'FL',
#   'LAKE',
#   'E'],
#  ['GATOR COUNTRY OFFROAD SERVICE & REPAIR',
#   '107 CALADIUM ROW',
#   'SEBRING',
#   'FL',
#   'HIGHLANDS',
#   'A'],
#  ['GATOR COUNTRY TRAPPERS', 'P.O. BOX 1024', 'ANTHONY', 'FL', 'MULTIPLE', 'E'],
#  ['GATOR COUPON BOOK', 'P O BOX 1487', 'SAFETY HARBOR', 'FL', 'PINELLAS', 'E'],
#  ['GATOR COURIER SERVICE',
#   '3353 OAK MEADOWS DR',
#   'MULBERRY',
#   'FL',
#   'POLK',
#   'E'],
#  ['GATOR COVE', '4076 S SUNCOAST BLVD', 'HOMOSASSA', 'FL', 'CITRUS', 'E'],
#  ['GATOR COVE TREASURES',
#   '2085 A1A SOUTH',
#   'SAINT AUGUSTINE',
#   'FL',
#   'MULTIPLE',
#   'E'],
#  ['GATOR CRANE CONSTRUCTION',
#   '2104 SUTHERLAND ROAD',
#   'LYNN HAVEN',
#   'FL',
#   'BAY',
#   'E'],
#  ['GATOR CRANE SERVICE',
#   '1451 PREMIER VILLAGE WAY',
#   'CLEARWATER',
#   'FL',
#   'PINELLAS',
#   'E'],
#  ['GATOR CRATE TRADING CO.', '580 BIRDSONG PL', 'SANIBEL', 'FL', 'LEE', 'E'],
#  ['GATOR CREEK BAR AND GRILL',
#   '4449 TUMBLEWEED RD',
#   'MIDDLEBURG',
#   'FL',
#   'CLAY',
#   'E'],
#  ['GATOR CREEK BLUEGRASS FESTIVAL',
#   '20420 69TH AVE EAST',
#   'BRADENTON',
#   'FL',
#   'MANATEE',
#   'E'],
#  ['GATOR CREEK DEMOLITION',
#   '505 CANADA COURT',
#   'PUNTA GORDA',
#   'FL',
#   'MULTIPLE',
#   'E'],
#  ['GATOR CREEK GOLF CLUB',
#   '9000 GATOR CREEK DR.',
#   'SARASOTA',
#   'FL',
#   'SARASOTA',
#   'A'],
#  ['GATOR CREEK MARINE',
#   '5000 DELTONA DRIVE',
#   'PUNTA GORDA',
#   'FL',
#   'CHARLOTTE',
#   'A'],
#  ['GATOR CREEK NURSERY',
#   'P.O. BOX 511272',
#   'PUNTA GORDA',
#   'FL',
#   'CHARLOTTE',
#   'E'],
#  ['GATOR CREEK TURF SERVICES',
#   '6234 SW 121ST AVE',
#   'LAKE BUTLER',
#   'FL',
#   'MULTIPLE',
#   'E'],
#  ['GATORCRETE', '5200 WEST NEWBERRY RD', 'GAINESVILLE', 'FL', 'ALACHUA', 'E'],
#  ['GATORCRETE COATINGS', 'PO BOX 303', 'MACCLENNY', 'FL', 'BAKER', 'E'],
#  ['GATOR CROSSFIT', '6750 NW 16TH ST', 'GAINESVILLE', 'FL', 'ALACHUA', 'E'],
#  ['GATOR CRUISE COMPANY',
#   '23015 NW 202 PLACE',
#   'HIGH SPRINGS',
#   'FL',
#   'ALACHUA',
#   'A'],
#  ['GATOR CRUISES',
#   '5745 SW 75TH ST # 269',
#   'GAINESVILLE',
#   'FL',
#   'MULTIPLE',
#   'E'],
#  ['GATOR CUSTOM BLINDS',
#   '9036 SW 102ND TERRACE',
#   'GAINESVILLE',
#   'FL',
#   'ALACHUA',
#   'E'],
#  ['GATOR CUSTOM CABINET DOORS',
#   '7725 FALCON STREET',
#   'JACKSONVILLE',
#   'FL',
#   'DUVAL',
#   'E'],
#  ['GATOR CUSTOM CONVERSIONS FABRICATION AND WELDING',
#   'P.O. BOX 1168',
#   'BELLEVIEW',
#   'FL',
#   'MARION',
#   'E'],
#  ['GATOR CUSTOM KEGERATORS',
#   '5631 NW 25TH TERRACE',
#   'GAINESVILLE',
#   'FL',
#   'MULTIPLE',
#   'E'],
#  ['GATOR CUSTOM RODS',
#   '12426 EARLY RUN LN',
#   'RIVERVIEW',
#   'FL',
#   'MULTIPLE',
#   'E'],
#  ['GATOR CUSTOMS', '10313 GREENLINKS DRIVE', 'TAMPA', 'FL', 'ALACHUA', 'E'],
#  ['GATOR CUSTOM SOFTWARE', 'PO BOX 155', 'OKALOOSA', 'FL', 'BAKER', 'E'],
#  ['GATOR CUT LAWN SERVICE', '1824 S EOLA DR', 'ORLANDO', 'FL', 'ORANGE', 'E'],
#  ['GATOR-CUT LAWN SERVICE',
#   '2307 SOUTH MILLS AVE.',
#   'ORLANDO',
#   'FL',
#   'MULTIPLE',
#   'C'],
#  ['GATOR CUT LAWN SERVICES', '34 SE 5TH ST', 'DANIA', 'FL', 'BROWARD', 'E'],
#  ['GATOR CUTS', '252 REGENCY ST', 'DAVENPORT', 'FL', 'POLK', 'E'],
#  ['GATOR CUTS', 'P.O. DRAWER 13475', 'GAINESVILLE', 'FL', 'ALACHUA', 'E'],
#  ['GATORCUTS LAWN MAINTENANCE',
#   '3400 CHAROW LANE',
#   'ORLANDO',
#   'FL',
#   'ORANGE',
#   'E'],
#  ['GATOR CUTS OUTDOOR SERVICES',
#   '320 SE 17TH PL',
#   'CAPE CORAL',
#   'FL',
#   'COLLIER',
#   'A'],
#  ['GATOR CUTZ', '450 NE 158 ST', 'MIAMI', 'FL', 'MULTIPLE', 'A'],
#  ['GATOR CYCLES', '2211 N DIXIE HWY', 'W PALM BCH', 'FL', 'PALM BEACH', 'E'],
#  ['GATORDATA AND MKT', '1100 SW 5TH ST', 'BOCA RATON', 'FL', 'MULTIPLE', 'A'],
#  ['GATOR DATE', '14755 SW 79 AVE', 'MIAMI', 'FL', 'MULTIPLE', 'E'],
#  ["GATOR DAVE'S", '2527 US HIGHWAY 19 NORTH', 'HOLIDAY', 'FL', 'PASCO', 'E'],
#  ["GATOR DAVE'S PLANTS & MAINTENANCE",
#   '5718 NW 210TH STREET',
#   'NEWBERRY',
#   'FL',
#   'MULTIPLE',
#   'E'],
#  ['GATOR DAVES TRADING CO', '31244 LAKE MACK RD', 'DELAND', 'FL', 'LAKE', 'E'],
#  ['GATOR DAWGS', '1534 SW 66TH DRIVE', 'GAINESVILLE', 'FL', 'ALACHUA', 'E'],
#  ['GATOR DECORATIVE COATING',
#   '211 ALABAMA STREET',
#   'CRESCENT CITY',
#   'FL',
#   'MULTIPLE',
#   'E'],
#  ['GATOR DELI, LLC', 'P.O. BOX 14036', 'GAINESVILLE', 'FL', 'ALACHUA', 'E'],
#  ['GATOR DEMO & CLEANUP',
#   '9 DOLPHIN DRIVE',
#   'VERO BEACH',
#   'FL',
#   'INDIAN RIVER',
#   'E'],
#  ['THE GATOR DEN',
#   '12189 S WILLIAMS STREET',
#   'DUNNELLON',
#   'FL',
#   'MARION',
#   'A'],
#  ['THE GATOR DEN MOTEL',
#   '12189 S WILLIAMS STREET',
#   'DUNNELLON',
#   'FL',
#   'MARION',
#   'A'],
#  ['GATORDENT',
#   '2614  TAMIAMI TRL N, SUITE 711',
#   'NAPLES',
#   'FL',
#   'MULTIPLE',
#   'E'],
#  ['GATOR DENTAL', 'P.O.BOX 10', 'HAWTHRONE', 'FL', 'ALACHUA', 'A'],
#  ['GATOR DENT REPAIR', '18054 SE 75TH ST', 'MICONPY', 'FL', 'ALACHUA', 'E'],
#  ['GATOR DEPOT',
#   '6820 LYONS TECHNOLOGY CIRCLE, STE 220',
#   'COCONUT CREEK',
#   'FL',
#   'PALM BEACH',
#   'A'],
#  ['GATOR DESIGN WEBSITES',
#   '675 TAMIAMI TRAIL',
#   'PORT CHARLOTTE',
#   'FL',
#   'CHARLOTTE',
#   'A'],
#  ['GATOR DETALING', '3031 NW 14TH ST', 'GAINESVILLE', 'FL', 'MULTIPLE', 'E'],
#  ['GATOR DIESEL', '6985 12TH ST', 'VERO BEACH', 'FL', 'MULTIPLE', 'A'],
#  ['GATOR DIRT WORX',
#   '8297 CHAMPIONS GATE BLVD #206',
#   'CHAMPIONSGATE',
#   'FL',
#   'POLK',
#   'E'],
#  ['GATOR DISCOUNT BEVERAGE',
#   '1103 NORTH TEMPLE AVENUE',
#   'STARKE',
#   'FL',
#   'BRADFORD',
#   'E'],
#  ['GATOR DISCOUNT BEVRAGE',
#   '1103 N TEMPLE AVE',
#   'STARKE',
#   'FL',
#   'BRADFORD',
#   'E'],
#  ['GATOR DISTRIBUTION',
#   '7851 SUPPLY DRIVE',
#   'FT MYERS',
#   'FL',
#   'MULTIPLE',
#   'E'],
#  ['GATOR DISTRIBUTOR',
#   '940 SWEETWATERLANE LANE # 214',
#   'BOCA RATON',
#   'FL',
#   'MULTIPLE',
#   'E'],
#  ['GATOR DIVE CLUB',
#   '10544 NW 31ST PLACE',
#   'GAINESVILLE',
#   'FL',
#   'ALACHUA',
#   'A'],
#  ['GATOR DIVING OPERATIONS',
#   '300 SHARWOOD DR.',
#   'NAPLES',
#   'FL',
#   'COLLIER',
#   'A'],
#  ['GATOR DJ', '621 RIVIERA LN.', 'PORT CHARLOTTE', 'FL', 'MULTIPLE', 'A'],
#  ['GATOR DOGS', '15583 NE 15TH AVE', 'STARKE', 'FL', 'MULTIPLE', 'E'],
#  ['GATOR DOGS ALMOST FAMOUS HOT DOGS',
#   '319 SW CHIPPEWA GLN',
#   'FT. WHITE',
#   'FL',
#   'COLUMBIA',
#   'E'],
#  ['GATOR DOLLAR', '3736SW 3RD PLACE', 'GAINESVILLE', 'FL', 'ALACHUA', 'E'],
#  ['GATOR DOLLAR', '451 PEACE CT', 'KISSIMMEE', 'FL', 'MULTIPLE', 'A'],
#  ['GATOR-DONE', '1311 NE 12TH AVE', 'OCALA', 'FL', 'MULTIPLE', 'A'],
#  ['GATOR DONE', '5700 LAKE OSBORNE DR', 'LAKE WORTH', 'FL', 'PALM BEACH', 'E'],
#  ['GATOR DONE',
#   '5700 LAKE OSBORNE DRIVE',
#   'LAKE WORTH',
#   'FL',
#   'PALM BEACH',
#   'C'],
#  ['GATOR DONE ADVENTURES',
#   '3813 NORTHGREEN AVE',
#   'TAMPA',
#   'FL',
#   'MULTIPLE',
#   'E'],
#  ['GATOR-DONE-GATORS', 'P.O. BOX 756', 'ZEPHYRHILLS', 'FL', 'PASCO', 'E'],
#  ['GATOR DONE HOME IMPROVEMENTS & REPAIR',
#   '438 BAHIA GRANDE AVENUE',
#   'PUNTA GORDA',
#   'FL',
#   'CHARLOTTE',
#   'E'],
#  ['GATOR-DONE LAWN CARE',
#   '943 NW 122ND TER',
#   'NEWBERRY',
#   'FL',
#   'ALACHUA',
#   'E'],
#  ['GATOR DOORS AND MILLWORK',
#   '10534 SW 114TH TERRACE',
#   'MIAMI',
#   'FL',
#   'MIAMI-DADE',
#   'E'],
#  ["GATOR DOUG'S BREWERY", '8333 ADELIO LANE', 'FORT MYERS', 'FL', 'LEE', 'A'],
#  ['GATOR DREDGING', '13630 50TH WAY N', 'CLEARWATER', 'FL', 'PINELLAS', 'A'],
#  ['GATOR DREDGING',
#   '13630 50TH. WAY NORTH',
#   'CLEARWATER',
#   'FL',
#   'PINELLAS',
#   'E'],
#  ['GATOR DREDGING', 'P.O. BOX 2223', 'ST. PETERSBURG', 'FL', 'PINELLAS', 'E'],
#  ['GATOR DRESS CODE',
#   '315 NW 13TH STREET',
#   'GAINESVILLE',
#   'FL',
#   'ALACHUA',
#   'E'],
#  ['GATOR DRUM LESSONS', 'PO BOX 5872', 'DELTONA', 'FL', 'VOLUSIA', 'E'],
#  ['GATOR-D-TAIL',
#   '1750 CUNNINGHAM DRIVE',
#   'SAINT CLOUD',
#   'FL',
#   'OSCEOLA',
#   'E'],
#  ['GATOR DUN LAWN MAINTENANCE, INC.',
#   '245 SE 148TH ST',
#   'SUMMERFIELD',
#   'FL',
#   'MULTIPLE',
#   'E'],
#  ['GATOR-DUN LAWN SERVICE & LANDSCAPE DESIGN',
#   '4117 HONOLULU DRIVE',
#   'SARASOTA',
#   'FL',
#   'SARASOTA',
#   'E'],
#  ['GAT-OR-DUNN  RITE', '623 VIRGINA AVE', 'HOLLY HILL', 'FL', 'VOLUSIA', 'E'],
#  ['GATOR DUST BUSTER',
#   '2510 NE 9TH STREET APT. 103',
#   'GAINESVILLE',
#   'FL',
#   'MULTIPLE',
#   'E'],
#  ["GATOR E-GO'S", '4125 NW 34TH DRIVE', 'GAONESVILLE', 'FL', 'MULTIPLE', 'E'],
#  ['GATOR ELECTRIC',
#   '1550 OLD US 27, LOT 299',
#   'CLEWISTON',
#   'FL',
#   'HENDRY',
#   'E'],
#  ['GATOR ELECTRIC', '2721 CATHERINE ST', 'KISSIMMEEE', 'FL', 'POLK', 'E'],
#  ['GATOR ELECTRICAL SERVICES',
#   '371671 HENRY SMITH ROAD',
#   'HILLIARD',
#   'FL',
#   'NASSAU',
#   'A'],
#  ['GATOR ELECTRIC AND COMMUNICATION',
#   '2843 MELALEUCA DRIVE',
#   'WEST PALM BEACH',
#   'FL',
#   'PALM BEACH',
#   'A'],
#  ['GATOR ELECTRIC AND COMMUNICATIONS',
#   '2101 S. MILITARY TRAIL',
#   'WEST PALM BEACH',
#   'FL',
#   'PALM BEACH',
#   'E'],
#  ['GATOR ELECTRIC CONTRACTING',
#   '1930 OAKVIEW CIRCLE',
#   'ST CLOUD',
#   'FL',
#   'OSCEOLA',
#   'E'],
#  ['GATOR ELECTRIC LLC',
#   '2721 CATHERINE ST',
#   'KISSIMMEE',
#   'FL',
#   'OSCEOLA',
#   'A'],
#  ['GATOR ELECTRIC SERVICE',
#   '744 BARNETT DR',
#   'LAKE WORTH',
#   'FL',
#   'PALM BEACH',
#   'E'],
#  ['GATOR ELECTRONICS',
#   '1151 27TH AVE',
#   'VERO BEACH',
#   'FL',
#   'INDIAN RIVER',
#   'E'],
#  ['GATOR ELECTRONICS',
#   '2179 42ND CT SW',
#   'VERO BEACH',
#   'FL',
#   'INDIAN RIVER',
#   'A'],
#  ['GATOREMART', '4318 SW 81 PL', 'GAINESVILLE', 'FL', 'ALACHUA', 'E'],
#  ['GATOR EMERGENCY ROADSIDE SERVICE',
#   '3609 OLD DELAND RD',
#   'DAYTONA BEACH',
#   'FL',
#   'VOLUSIA',
#   'E'],
#  ['GATOR ENCOUNTER',
#   '2927 WEST KNIGHTS AVENUE',
#   'TAMPA',
#   'FL',
#   'HILLSBOROUGH',
#   'A'],
#  ['GATO RENOVATION', '13 CARDINAL DR', 'LONGWOOD', 'FL', 'MULTIPLE', 'E'],
#  ['GATOR ENTERPRISE', '19551 41 SOUTH', 'FT MYERS', 'FL', 'MULTIPLE', 'E'],
#  ['GATOR ENTERPRISES', '25424 COLMAR AVE', 'SORRENTO', 'FL', 'LAKE', 'A'],
#  ['GATOR ENVIRONMENTAL SITEWORK',
#   '7290 WAELTI DRIVE',
#   'MELBOURNE',
#   'FL',
#   'BREVARD',
#   'A'],
#  ['GATOR EXCVATION',
#   '1003 S.E. 5TH COURT',
#   'DEERFIELD BEACH',
#   'FL',
#   'BROWARD',
#   'E'],
#  ['GATOR EXPRESS', '3215 N. 29TH STREET', 'TAMPA', 'FL', 'HILLSBOROUGH', 'A'],
#  ['GATOR EXPRESS COURIER',
#   '5920 KNOLLWOOD RD',
#   'GREEN COVE SPRINGS',
#   'FL',
#   'MULTIPLE',
#   'I'],
#  ['GATOR EXPRESS COURIER',
#   '5920 KNOLLWOOD ROAD',
#   'GREEN COVE SPRINGS',
#   'FL',
#   'MULTIPLE',
#   'C'],
#  ['GATOR FABRICATION',
#   '1432 SW 26 AVE',
#   'FORT LAUDERDALE',
#   'FL',
#   'MULTIPLE',
#   'E'],
#  ['GATORFACE.COM',
#   '1610 BRILLIANT CUT WAY',
#   'VALRICO',
#   'FL',
#   'HILLSBOROUGH',
#   'A'],
#  ['GATOR FAMILY CHIROPRACTIC',
#   '4423 NW 6TH PLACE',
#   'GAINESVILLE',
#   'FL',
#   'ALACHUA',
#   'A'],
#  ['GATOR FAMILY THEME PARK',
#   '4685 HIGHWAY 98 SOUTH',
#   'LAKELAND',
#   'FL',
#   'POLK',
#   'E'],
#  ['GATOR FANTASY FACES',
#   'C/O TIM DEEGAN CPA',
#   'GAINESVILLE',
#   'FL',
#   'ALACHUA',
#   'E'],
#  ['GATOR FASHIONS',
#   '4213 N.W. 16TH BLVD',
#   'GAINESVILLE',
#   'FL',
#   'ALACHUA',
#   'E'],
#  ['GATOR FENCE CO.', '15206 PARETE RD.', 'JACKSONVILLE', 'FL', 'DUVAL', 'E'],
#  ['GATOR FENCE', '4608 ZOLTAN DR.', 'TITUSVILLE', 'FL', 'BREVARD', 'E'],
#  ['GATOR FENCING', 'P.O BOX 663', 'LEHIGH ACRES', 'FL', 'MULTIPLE', 'E'],
#  ['GATOR FIBERGLASS REPAIR',
#   '20963 NW 196TH AVENUE',
#   'HIGH SPRINGS',
#   'FL',
#   'ALACHUA',
#   'E'],
#  ['GATORFIEDS', 'P O BOX 822', 'GAINESVILLE', 'FL', 'ALACHUA', 'E'],
#  ['GATOR FIELD SERVICES',
#   '109 ORANGE BLOSSOM CIRCLE',
#   'ALTAMONTE SPRINGS',
#   'FL',
#   'MULTIPLE',
#   'E'],
#  ['GATOR FIELD SERVICES',
#   '12553 SW 211 ST.',
#   'MIAMI',
#   'FL',
#   'MIAMI-DADE',
#   'E'],
#  ['GATOR FINANCIAL GROUP',
#   '3557 SW 19 AVENUE, #9',
#   'GAINESVILLE',
#   'FL',
#   'MULTIPLE',
#   'E'],
#  ['GATORFINDER', '2451 QUIET WATERS LOOP', 'OCOEE', 'FL', 'ORANGE', 'E'],
#  ['GATORFIN POOL AND SPA CARE',
#   'PO BOX 222',
#   'BOCA RATON',
#   'FL',
#   'PALM BEACH',
#   'E'],
#  ['GATOR FIRE ALARMS',
#   '1032 S MAIN STREET',
#   'GAINESVILLE',
#   'FL',
#   'ALACHUA',
#   'E'],
#  ['GATOR FIRE ALARM AND SECURITY',
#   '1032 SOUTH MAIN STREET',
#   'GAINESVILLE',
#   'FL',
#   'ALACHUA',
#   'E'],
#  ['GATOR FIREARM ACADEMY',
#   '4600 NW 41ST PLACE',
#   'GAINESVILLE',
#   'FL',
#   'ALACHUA',
#   'E'],
#  ['GATOR FIRE EQUIPMENT CO',
#   '1032 S MAIN ST',
#   'GAINESVILLE',
#   'FL',
#   'ALACHUA',
#   'E'],
#  ['GATOR FIRE EQUIPMENT',
#   '1032 SOUTH MAIN STREET',
#   'GAINESVILLE',
#   'FL',
#   'ALACHUA',
#   'A'],
#  ['GATOR FIRE EQUIPMENT CO.',
#   '1032 SOUTH MAIN STREET',
#   'GAINESVILLE',
#   'FL',
#   'ALACHUA',
#   'A'],
#  ['GATOR FIRE EQUIPMENT CO, INC.',
#   '1032 S MAIN ST',
#   'GAINESVILLE',
#   'FL',
#   'ALACHUA',
#   'E'],
#  ['GATOR FIRE EQUIPMENT COMPANY, INC.',
#   '1032 SOUTH MAIN STREET',
#   'GAINESVILLE',
#   'FL',
#   'ALACHUA',
#   'A'],
#  ['GATOR FIRE EQUIPMENT CO., INC.',
#   '1032 SOUTH MAIN STREET',
#   'GAINESVILLE',
#   'FL',
#   'ALACHUA',
#   'A'],
#  ['GATOR FIRE & WATER RESTORATION SERVICE',
#   '13833 WELLINGTON TRACE RD.',
#   'WEST PALM BEACH',
#   'FL',
#   'PALM BEACH',
#   'C'],
#  ['GATOR FIRE & WATER RESTORATION SERVICE',
#   '13833 WELLINGTON TRACE RD.',
#   'WEST PALM BEACH',
#   'FL',
#   'PALM BEACH',
#   'E'],
#  ['GATOR FIREWORKS', 'PO BOX 4072', 'BELLEVIEW', 'FL', 'MARION', 'A'],
#  ['GATOR FITNESS AND TRAINING',
#   '6714 NW 16TH ST.',
#   'GAINESVILLE',
#   'FL',
#   'ALACHUA',
#   'E'],
#  ['GATORFIZZ', '3527 SW 20TH AVE', 'GAINESVILLE', 'FL', 'ALACHUA', 'E'],
#  ['GATOR FLIES', '211 24TH STREET #302', 'COCOA BEACH', 'FL', 'BREVARD', 'E'],
#  ['GATORFOOD.COM',
#   '408 W UNIVERSITY AVE.',
#   'GAINESVILLE',
#   'FL',
#   'ALACHUA',
#   'E'],
#  ['GATORFOOD.COM',
#   '818 W UNIVERSITY AVE',
#   'GAINESVILLE',
#   'FL',
#   'ALACHUA',
#   'E'],
#  ['GATORFOOD.COM',
#   '818 W. UNIVERSITY AVENUE, STE. 209',
#   'GAINESVILLE',
#   'FL',
#   'ALACHUA',
#   'E'],
#  ['GATORFOOD.COM',
#   '818 WEST UNIVERSITY AVE.    SUITE-215',
#   'GAINESVILLE',
#   'FL',
#   'ALACHUA',
#   'C'],
#  ['GATOR FOOD DISTRIBUTOR',
#   '4044 DOTTIE RD.',
#   'JACKSONVILLE',
#   'FL',
#   'DUVAL',
#   'E'],
#  ['GATOR FOOD MART', '528 NW 8TH AVENUE', 'GAINESVILLE', 'FL', 'ALACHUA', 'A'],
#  ['GATOR FORD', '11780 TAMPA GATEWAY BLVD', 'SEFFNER', 'FL', 'MULTIPLE', 'A'],
#  ['GATOR FORD',
#   '11780 TAMPA GATEWAY BOULEVARD',
#   'SEFFNER',
#   'FL',
#   'HILLSBOROUGH',
#   'E'],
#  ['GATOR FRAMING',
#   '% ROBERT CRIBBS JR.',
#   'HIGH SPRINGS',
#   'FL',
#   'COLUMBIA',
#   'E'],
#  ['GATOR FRED', '5360 EHRLICH ROAD', 'TAMPA', 'FL', 'MULTIPLE', 'A'],
#  ["GATOR FRED'S", '1423 BAYTHORN DR', 'WESLEY CHAPEL', 'FL', 'PINELLAS', 'E'],
#  ["GATOR FRED'S",
#   '28933 LONG MEADOW LOOP',
#   'WESLEY CHAPEL',
#   'FL',
#   'HILLSBOROUGH',
#   'E'],
#  ['GATOR FREIGHTORS', 'P.O. BOX 643', 'HIGH SPRINGS', 'FL', 'ALACHUA', 'E'],
#  ['GATOR GABAGE VALET',
#   '25012 HYDE PARK BLVD',
#   "LAND O' LAKES",
#   'FL',
#   'MULTIPLE',
#   'E'],
#  ['GATOR GADGETS',
#   '11780 TAMPA GATEWAY BOULEVARD',
#   'TAMPA',
#   'FL',
#   'HILLSBOROUGH',
#   'E'],
#  ['GATOR GAINES CONSTRUCTION LLC',
#   '710 MEADOW ST',
#   'SANFORD',
#   'FL',
#   'SEMINOLE',
#   'A'],
#  ['GATOR GALLOWS GUIDE SERVICES',
#   '2727 E OAKLAND PARK BLD #200',
#   'FT. LAUDERDALE',
#   'FL',
#   'GLADES',
#   'A'],
#  ['GATOR GALLOWS GUIDE SERVICES',
#   '2727 E OAKLAND PARK BLD #200',
#   'FT. LAUDERDALE',
#   'FL',
#   'GLADES',
#   'A'],
#  ['GATOR GALLOWS GUIDE SERVICES',
#   '2727 E OAKLAND PARK BLVD #200',
#   'FORT LAUDERDALE',
#   'FL',
#   'GLADES',
#   'A'],
#  ['GATOR GAMES', '3541 FOWLER STREET', 'FT MYERS', 'FL', 'LEE', 'E'],
#  ['GATOR GAMES', '3541 FOWLER STREET', 'FORT MYERS', 'FL', 'LEE', 'E'],
#  ['GATOR GAMES', '3541 FOWLER STREET', 'FORT MYERS', 'FL', 'LEE', 'E'],
#  ['GATORGAMEZONE', '5999 LAKE POINTE DR. 603', 'ORLANDO', 'FL', 'ORANGE', 'E'],
#  ['GATORGAMING.NET',
#   '3610 NW 42 TERRACE',
#   'GAINESVILLE',
#   'FL',
#   'ALACHUA',
#   'E'],
#  ['GATOR GARAGE', '1602 NW 6TH STREEET', 'GAINESVILLE', 'FL', 'ALACHUA', 'A'],
#  ['GATOR GARAGE', '1602 NW 6TH STREET', 'GAINESVILLE', 'FL', 'ALACHUA', 'E'],
#  ['GATOR GARDENS', '18975 SW 232ND ST', 'MIAMI', 'FL', 'MIAMI-DADE', 'C'],
#  ['GATOR GARDENS', '18975 SW 232ND STREET', 'MIAMI', 'FL', 'MIAMI-DADE', 'E'],
#  ['GATOR GAS', 'P.O. BOX 411', 'INVERNESS', 'FL', 'CITRUS', 'E'],
#  ['GATOR GASKET GUY', '105 PIPER BLVD', 'PORT ORANGE', 'FL', 'ALACHUA', 'E'],
#  ['GATOR GASKET GUY',
#   '18 LAZY EIGHT DRIVE',
#   'PORT ORANGE',
#   'FL',
#   'MULTIPLE',
#   'C'],
#  ['GATOR GASKET LLC',
#   '106 WEST PARK ST',
#   'TARPON SPRINGS',
#   'FL',
#   'MULTIPLE',
#   'E'],
#  ['GATOR GATE MANUFACTURING',
#   '2589 S FEDERAL HWY',
#   'FT PIERCE',
#   'FL',
#   'ST. LUCIE',
#   'E'],
#  ['GATOR GATES', '3705 BIG BASS ROAD', 'KISSIMMEE', 'FL', 'OSCEOLA', 'E'],
#  ['GATOR GATEWORKS',
#   '1032 SOUTH MAIN STREET',
#   'GAINESVILLE',
#   'FL',
#   'ALACHUA',
#   'E'],
#  ['GATOR GAUNTLET',
#   '5745 SE 75TH STREET # 305',
#   'GAINESVILLE',
#   'FL',
#   'ALACHUA',
#   'E'],
#  ['GATORGEAR', '7235 BONNEVAL RD.', 'JACKSONVILLE', 'FL', 'DUVAL', 'E'],
#  ['GATOR GECKOS', '2158 NW 5TH AVENUE', 'GAINESVILLE', 'FL', 'ALACHUA', 'A'],
#  ['GATOR GENERATOR',
#   '1220 N.W. 53RD AVENUE',
#   'GAINESVILLE',
#   'FL',
#   'ALACHUA',
#   'E'],
#  ['GATOR GENERATOR MAINTENANCE',
#   '221 MAPLEWOOD LANE',
#   'GREENACRES',
#   'FL',
#   'PALM BEACH',
#   'E'],
#  ['GATOR GIFTS & BAIT',
#   '920 S LAKESHORE BLVD',
#   'LAKE WALES',
#   'FL',
#   'POLK',
#   'E'],
#  ['GATOR GILL',
#   '1701 EAST LINDA STREET',
#   'PLANT CITY',
#   'FL',
#   'HILLSBOROUGH',
#   'A'],
#  ['GATOR GIRL GIFTS', '817 S MILLS AVE', 'ORLANDO', 'FL', 'ORANGE', 'E'],
#  ['GATOR GIRLS', '23100 GLEN AVE', 'PORT CHARLOTTE', 'FL', 'CHARLOTTE', 'E'],
#  ['GATOR GLADES', '3288 WAYMAN ROAD', 'MOORE HAVEN', 'FL', 'GLADES', 'A'],
#  ['GATOR GLASS',
#   '8087 MONETARY DR E-4',
#   'WEST PALM BEACH',
#   'FL',
#   'PALM BEACH',
#   'E'],
#  ['GATOR GLASS & MIRROR',
#   '15117 N STATE RD 121',
#   'GAINESVILLE',
#   'FL',
#   'ALACHUA',
#   'E'],
#  ['GATOR GLASS REFURBISHING',
#   '857 LAGUNA DRIVE',
#   'FERNANDINA BEACH',
#   'FL',
#   'MULTIPLE',
#   'E'],
#  ['GATOR GLASS TINTING', '2340 PLUM AVENUE', 'AUBURNDALE', 'FL', 'POLK', 'E'],
#  ['GATOR GLAZE',
#   '9468 SPRING CIRCLE',
#   'PORT CHARLOTTE',
#   'FL',
#   'MULTIPLE',
#   'A'],
#  ['GATOR GLIDERS LLC',
#   '6724 NW 36TH DRIVE',
#   'GAINESVILLE',
#   'FL',
#   'ALACHUA',
#   'E'],
#  ['GATOR GLITZ', '2915 ABBEY LAKE ROAD', 'CLEARWATER', 'FL', 'PINELLAS', 'E'],
#  ['GATOR GOLDBUG',
#   '5320 SW 82ND TERRACE',
#   'GAINESVILLE',
#   'FL',
#   'MULTIPLE',
#   'E'],
#  ['GATOR GOLF', '6586 INTERNATIONAL DR', 'ORLANDO', 'FL', 'MULTIPLE', 'E'],
#  ['GATOR GOLF BALLS', '1825 VALLEY RIDGE LOOP', 'CLERMONT', 'FL', 'LAKE', 'E'],
#  ['GATOR GOLF CAR PARTS AND ACCESSORIES',
#   '1301 C ROAD',
#   'LOXAHATCHEE',
#   'FL',
#   'PALM BEACH',
#   'E'],
#  ['GATOR GOLF CARTS', '8341 G SW 90TH LN', 'OCALA', 'FL', 'MARION', 'E'],
#  ['GATOR GOLF JOHN',
#   '11470 NW 21ST COURT',
#   'PLANTATION',
#   'FL',
#   'BROWARD',
#   'A'],
#  ['GATOR GOLF OF THE KEYS',
#   '93160 OVERSEAS HIGHWAY',
#   'TAVERNIER',
#   'FL',
#   'MONROE',
#   'E'],
#  ['GATOR GOLF OF THE KEYS',
#   '96000 OVERSEAS HWY. (W-45)',
#   'KEY LARGO',
#   'FL',
#   'MONROE',
#   'E'],
#  ['THE GATOR GOLF SHOP',
#   '3501 SW 2ND AVENUE',
#   'GAINESVILLE',
#   'FL',
#   'ALACHUA',
#   'E'],
#  ['GATOR GOLF TOUR', '830 A1A S', 'PONTE VEDRA BCH', 'FL', 'ST. JOHNS', 'E'],
#  ['GATOR GOODIES',
#   '1691 PONCE DE LEON COURT',
#   'ORANGE PARK',
#   'FL',
#   'CLAY',
#   'E'],
#  ['GATOR GOURMET GIFTS & GOODIES',
#   '4206 W. ANGELES CT.',
#   'TAMPA',
#   'FL',
#   'HILLSBOROUGH',
#   'E'],
#  ['GATOR GRADING', '11245 KIJIK TRAIL', 'GROVELAND', 'FL', 'LAKE', 'E'],
#  ['GATOR GRANITE', '2533 NE 15TH ST.', 'POMPANO BEACH', 'FL', 'MULTIPLE', 'E'],
#  ['GATOR GRANITE', '5932 SE 229TH TERR', 'HAWTHORNE', 'FL', 'ALACHUA', 'E'],
#  ['GATOR GRANITE INSTALLS, LLC',
#   '81 HANNA COLE DR',
#   'ST. AUGUSTINE',
#   'FL',
#   'MULTIPLE',
#   'E'],
#  ['GATOR GRAPHICS',
#   '850 NE 125TH TERRACE ROAD',
#   'SILVER SPRINGS',
#   'FL',
#   'MARION',
#   'E'],
#  ['GATOR GRAPHICS & DESIGN',
#   '6070 LAKE AVENUE',
#   'SANFORD',
#   'FL',
#   'SEMINOLE',
#   'E'],
#  ['GATOR GRAPHICS & DESIGN',
#   '6070 LAKE AVENUE',
#   'SANFORD',
#   'FL',
#   'MULTIPLE',
#   'E'],
#  ['GATOR GRAPHICS OF FLORIDA',
#   '8559 SHAWE WAY',
#   'BOCA RATON',
#   'FL',
#   'PALM BEACH',
#   'C'],
#  ['GATOR GRAPHICS OF PALM BEACH',
#   '3345 B MERIDIAN WAY NORTH',
#   'PALM BEACH GARDENS',
#   'FL',
#   'PALM BEACH',
#   'E'],
#  ['GATOR GRAPHIX', '4609 SW 13TH AVE', 'CAPE CORAL', 'FL', 'MULTIPLE', 'E'],
#  ['GATOR GRAPHIX AND DESIGNS',
#   '5120 36TH AVE S',
#   'TAMPA',
#   'FL',
#   'HILLSBOROUGH',
#   'E'],
#  ['GATOR GRAPHIX SIGNS & ART',
#   '4627 ENTERPRISE AVE UNIT C',
#   'NAPLES',
#   'FL',
#   'COLLIER',
#   'E'],
#  ['GATOR GRAPHIX SIGNS & ART',
#   '950 COMMERCIAL BLVD.',
#   'NAPLES',
#   'FL',
#   'COLLIER',
#   'E'],
#  ['GATOR GRAPICS OF JACKSONVILLE',
#   '7032 EAGLES PERCH DR.',
#   'JACKSONVILLE',
#   'FL',
#   'DUVAL',
#   'E'],
#  ['GATOR GRASS', '9527 N.E. 65 LN', 'BRONSON', 'FL', 'MULTIPLE', 'E'],
#  ['GATOR GRASSING', 'RT. 5 BOX 4260', 'LAKE BUTLER', 'FL', 'UNION', 'E'],
#  ['GATOR GRASS LAWNS',
#   '12165 TRAVERTINE TRAIL',
#   'JACKSONVILLE',
#   'FL',
#   'MULTIPLE',
#   'E'],
#  ['GATOR GRAZERS', 'P O BOX 244', 'MELROSE', 'FL', 'ALACHUA', 'E'],
#  ['GATOR GREEK PAGES',
#   '10190 SCOTT MILL RD.',
#   'JACKSONVILLE',
#   'FL',
#   'MULTIPLE',
#   'E'],
#  ['GATOR GREEN', '2008 SW 72ND ST', 'GAINESVILLE', 'FL', 'ALACHUA', 'E'],
#  ['THE GATOR GRILL', '1006 N US HWY. 27', 'WESTON', 'FL', 'BROWARD', 'A'],
#  ['THE GATOR GRILL',
#   '31190 SW 194 AVENUE',
#   'HOMESTEAD',
#   'FL',
#   'MULTIPLE',
#   'A'],
#  ['GATOR GRILL', '31190 SW 194 AVENUE', 'HOMESTEAD', 'FL', 'MULTIPLE', 'A'],
#  ['GATOR GRILL AND CATERING',
#   '6280 LITTLE LAKE GENEVA RD',
#   'KEYSTONE HEIGHTS',
#   'FL',
#   'CLAY',
#   'E'],
#  ['THE GATOR GRILLE',
#   '4001 TAMIAMI TRAIL NORTH, SUITE 350',
#   'NAPLES',
#   'FL',
#   'COLLIER',
#   'C'],
#  ['THE GATOR GRILLE',
#   '4001 TAMIAMI TRAIL, SUITE 350',
#   'NAPLES',
#   'FL',
#   'COLLIER',
#   'E'],
#  ['THE GATOR GRILLE',
#   "8156 FIDDLER'S CREEK PKWY.",
#   'NAPLES',
#   'FL',
#   'COLLIER',
#   'A'],
#  ['GATOR GRILL OF UMATILLA',
#   'POST OFFICE BOX 1389',
#   'EUSTIS',
#   'FL',
#   'LAKE',
#   'A'],
#  ['GATOR GRIP', '12800 US HWY 98', 'SEBRING', 'FL', 'HIGHLANDS', 'E'],
#  ['GATOR GRIP FLOORS',
#   '10917 KENBROOK DR.',
#   'RIVERVIEW',
#   'FL',
#   'MULTIPLE',
#   'E'],
#  ['GATOR GRLL', '36650  SW 192  AVE', 'HOMETSTEAD', 'FL', 'MIAMI-DADE', 'E'],
#  ['GATOR GROCERY',
#   '2005 NW 181 TERRACE',
#   'PEMBROKE PINES',
#   'FL',
#   'MULTIPLE',
#   'A'],
#  ['GATOR GROUNDS KEEPING',
#   '7908 RUSTY OAKS DR.',
#   'NEW PORT RICHEY',
#   'FL',
#   'PASCO',
#   'E'],
#  ['GATOR GROUNDWORKS',
#   '621 E DEL MONTE AVE',
#   'CLEWISTON',
#   'FL',
#   'HENDRY',
#   'A'],
#  ['GATOR GROUP', '884 17TH STREET', 'VERO BEACH', 'FL', 'INDIAN RIVER', 'E'],
#  ['GATOR GROUP', '916 17TH STREET', 'VERO BEACH', 'FL', 'INDIAN RIVER', 'A'],
#  ['GATOR GROUT, INC.',
#   '11401 TULLAMORE PLACE',
#   'TAMPA',
#   'FL',
#   'HILLSBOROUGH',
#   'E'],
#  ['GATOR GROWERS NURSERY', 'PO BOX 507', 'PLYMOUTH', 'FL', 'ORANGE', 'A'],
#  ['GATOR GUIDE', 'P O BOX 14257', 'GAINESVILLE', 'FL', 'ALACHUA', 'A'],
# ...
#   'FL',
#   'HERNANDO',
#   'E'],
#  ['GATOR NUTRITION CLERMONT',
#   '7207 HALTON COURT',
#   'WINDERMERE',
#   'FL',
#   'LAKE',
#   'E'],
#  ['GATOR NUTS', '460 39TH AVE NE', 'NAPLES', 'FL', 'COLLIER', 'A'],
#  ['GATO-RODZ', '174 OCALA DRIVE', 'TAVERNIER', 'FL', 'MONROE', 'A'],
#  ['GATOR OFFICE PRODUCTS FURNITURE',
#   '11747 PHILIPS HIGHWAY',
#   'JACKSONVILLE',
#   'FL',
#   'DUVAL',
#   'A'],
#  ['GATORONICS', '1505 FORT CLARKE BLVD', 'GAINESVILLE', 'FL', 'ALACHUA', 'E'],
#  ['GATOR ONLINE', '12424 93RD AVE N', 'SEMINOLE', 'FL', 'ALACHUA', 'E'],
#  ['GATOR OUTFITTERS', '6070 LAKE AVENUE', 'SANFORD', 'FL', 'MULTIPLE', 'A'],
#  ['GATOR PACKAGING',
#   '2430 VANDERBILT BEACH RD. #108',
#   'NAPLES',
#   'FL',
#   'COLLIER',
#   'E'],
#  ['GATORPACK SHIPPING SUPPLIES',
#   'PO BOX 152262',
#   'TAMPA',
#   'FL',
#   'HILLSBOROUGH',
#   'E'],
#  ['GATOR PAINTBALL EXTREME',
#   '11122 HOUSTON AVE.',
#   'HUDSON',
#   'FL',
#   'PASCO',
#   'E'],
#  ['GATOR PAINTBALL XTREME',
#   '9331 STERLING LANE',
#   'PORT RICHEY',
#   'FL',
#   'PASCO',
#   'E'],
#  ['GATOR PAINTERS', '1554 NW 21ST AVE', 'GAINESVILLE', 'FL', 'ALACHUA', 'A'],
#  ['GATOR PAINT II',
#   '1092 PONCE DE LEON BLVD.',
#   'ST AUGUSTINE',
#   'FL',
#   'ST. JOHNS',
#   'E'],
#  ['GATOR PAINTING COMPANY',
#   '10151 UNIVERSITY BLVD SUITE 226',
#   'ORLANDO',
#   'FL',
#   'ORANGE',
#   'C'],
#  ['GATOR PAINTING CO',
#   '7380 S OCEAN DRIVE',
#   'JENSEN BEACH',
#   'FL',
#   'MARTIN',
#   'E'],
#  ['GATOR PAINTING', '813 SENATE CT', 'TAMPA', 'FL', 'HILLSBOROUGH', 'E'],
#  ['GATOR PAINTING', 'P O BOX 701794', 'ST CLOUD', 'FL', 'MULTIPLE', 'E'],
#  ['GATOR PAINTING CONTRACTORS',
#   'ONE SAN JOSE PLACE #14-B',
#   'JACKSONVILLE',
#   'FL',
#   'DUVAL',
#   'C'],
#  ['GATOR PAINTING SOLUTIONS',
#   'PO BOX 250',
#   'WORTHINGTON SPRIINGS',
#   'FL',
#   'MULTIPLE',
#   'E'],
#  ['GATOR PAINTING AND WATERPROOFING',
#   '6385 SAFFORD TERRACE',
#   'NORTH PORT',
#   'FL',
#   'SARASOTA',
#   'E'],
#  ['GATOR OF PALM BAY', '1101 PALM BAY RD.', 'MELBOURNE', 'FL', 'BREVARD', 'A'],
#  ['GATOR PALMS', '18525 5TH AVE', 'ORLANDO', 'FL', 'ORANGE', 'A'],
#  ['GATORPANTIES.COM',
#   '5663 FOX HOLLOW DRIVE',
#   'BOCA RATON',
#   'FL',
#   'BROWARD',
#   'E'],
#  ['GATOR PAPER COMPANY', 'P.O. BOX 1806', 'NORFOLK', 'VA', 'ORANGE', 'E'],
#  ['GATOR PARK', '2811 NW 58TH BLVD', 'GAINESVILLE', 'FL', 'ALACHUA', 'A'],
#  ['GATOR PARKING', '2811 NW 58TH BLVD', 'GAINESVILLE', 'FL', 'ALACHUA', 'A'],
#  ['GATOR PARTY SOLUTIONS',
#   '14260 W NEWBERRY ROAD #209',
#   'NEWBERRY',
#   'FL',
#   'ALACHUA',
#   'E'],
#  ['GATOR PATCH', 'P O BOX 1856', 'MELROSE', 'FL', 'ALACHUA', 'E'],
#  ['GATOR PATROL', '3750 PACKARD AVE', 'ST.CLOUD', 'FL', 'OSCEOLA', 'A'],
#  ['GATOR PATROL', '3750 PACKARD AVE.', 'ST.CLOUD', 'FL', 'OSCEOLA', 'C'],
#  ['GATOR PAVEMENT MARKINGS',
#   '1181 RIVAGE CIRCLE',
#   'BRANDON',
#   'FL',
#   'HILLSBOROUGH',
#   'E'],
#  ['GATOR PAVEMENT MARKINGS',
#   'P.O. BOX 756',
#   'BRANDON',
#   'FL',
#   'HILLSBOROUGH',
#   'E'],
#  ['GATOR PAWN OF SPRING HILL',
#   '2132 MARINER BLVD',
#   'SPRING HILL',
#   'FL',
#   'HERNANDO',
#   'C'],
#  ['GATOR PAWN OF SPRING HILL',
#   '2132 MARINER BLVD.',
#   'SPRING HILL',
#   'FL',
#   'HERNANDO',
#   'E'],
#  ['GATOR PAYROLL SERVICES',
#   '2339 NE 19TH DRIVE',
#   'GAINESVILLE',
#   'FL',
#   'ALACHUA',
#   'A'],
#  ['GATORPC.COM', '5500 SE SCHOONER OAKS WAY', 'STUART', 'FL', 'MULTIPLE', 'E'],
#  ['GATOR PC REPAIR',
#   '355 SOUTH LAWRENCE BLVD',
#   'KEYSTONE HEIGHTS',
#   'FL',
#   'CLAY',
#   'E'],
#  ['GATOR PERFECT SOLUTIONS', 'PO BOX 792', 'LEHIGH ACRES', 'FL', 'LEE', 'A'],
#  ['GATOR PERFORMANCE & ACCESSORIES',
#   '3745 NW 50TH STREET',
#   'MIAMI',
#   'FL',
#   'MIAMI-DADE',
#   'E'],
#  ['GATOR PERMITS', '1623-7 RED CEDAR DR', 'FORT MYERS', 'FL', 'LEE', 'C'],
#  ['GATOR PERMITS', '7584 CAMERON CIRCLE', 'FORT MYERS', 'FL', 'LEE', 'A'],
#  ['GATOR PEST MANAGEMENT',
#   '5513 BAKER AVE.',
#   'HAINES CITY',
#   'FL',
#   'POLK',
#   'E'],
#  ['GATOR PEST MANAGEMENT',
#   'GATOR PEST MANAGEMENT',
#   'THONOTOSASSA',
#   'FL',
#   'MULTIPLE',
#   'E'],
#  ['GATOR PEST SOLUTIONS',
#   'GATOR PEST SOLUTIONS',
#   'THONOTOSASSA',
#   'FL',
#   'MULTIPLE',
#   'A'],
#  ['GATOR PETROLEUM', '525 NESBIT ST.', 'PUNTA GORDA', 'FL', 'CHARLOTTE', 'E'],
#  ['GATOR PHARM COMPOUNDING LAB',
#   '5 N MAIN AVE',
#   'LAKE PLACID',
#   'FL',
#   'HIGHLANDS',
#   'A'],
#  ['GATOR PHOTO', '6352 NW 18TH DR', 'GAINESVILLE', 'FL', 'ALACHUA', 'E'],
#  ['GATOR PHOTOS', '2 SLEEPY HOLLOW COVE', 'LONGWOOD', 'FL', 'MULTIPLE', 'E'],
#  ['GATOR PHYSICAL THERAPY',
#   '3554 B GARDENS EAST DRIVE',
#   'PALM BEACH GARDENS',
#   'FL',
#   'PALM BEACH',
#   'E'],
#  ['GATOR PILOT/ ESCORT', 'PO BOX 95', 'MELROSE', 'FL', 'MULTIPLE', 'E'],
#  ['THE GATOR PIT', '1330 PALM DRIVE', 'APOPKA', 'FL', 'SEMINOLE', 'E'],
#  ['GATOR PITA', 'PO BOX 14077', 'GAINESVILLE', 'FL', 'ALACHUA', 'E'],
#  ['GATOR PIT CATERING',
#   '1631 SW 16TH ST',
#   'OKEECHOBEE',
#   'FL',
#   'OKEECHOBEE',
#   'E'],
#  ['GATOR PLAYGROUNDS', '4226 N C.R. 426', 'GENEVA', 'FL', 'SEMINOLE', 'E'],
#  ['GATOR PLAZA', '4137 W VINE ST', 'KISSIMMEE', 'FL', 'OSCEOLA', 'E'],
#  ['GATOR PLAZA', '600 N. PEARL STREET', 'DALLAS', 'TX', 'ALACHUA', 'E'],
#  ['GATOR PLUMBING', 'PO BOX 511', 'LADY LAKE', 'FL', 'LAKE', 'E'],
#  ['GATOR PLUMBING AIR CONDITIONER',
#   '21 SE 10 ST.',
#   'DEERFIELD BEACH',
#   'FL',
#   'BROWARD',
#   'C'],
#  ['GATOR PLUMBING AIR CONDITIONING',
#   '21 SE 10 STREET',
#   'DEERFIELD BEACH',
#   'FL',
#   'BROWARD',
#   'E'],
#  ['GATOR PLUMBING SUPPLY OF SOUTH FLORIDA',
#   '1084 SW 1 WAY',
#   'DEERFIELD BEACH',
#   'FL',
#   'BROWARD',
#   'E'],
#  ['GATOR POOL CARE', '974 CITRUS AVENUE', 'PALM BAY', 'FL', 'BREVARD', 'A'],
#  ['GATOR POOL CHELMICALS',
#   '3902 UNIT B CRILL AVE',
#   'PALATKA',
#   'FL',
#   'PUTNAM',
#   'E'],
#  ['GATOR POOL CLEANING',
#   '708 E. CARACAS ST.',
#   'TAMPA',
#   'FL',
#   'HILLSBOROUGH',
#   'E'],
#  ['GATOR POOLS',
#   '13088 56TH PLACE N',
#   'ROYAL PALM BEACH',
#   'FL',
#   'PALM BEACH',
#   'E'],
#  ['GATOR POOLS', '2070 NW 79 AVE', 'MIAMI', 'FL', 'MIAMI-DADE', 'E'],
#  ['GATOR POOLS', '2139 SNOOK DRIVE', 'NAPLES', 'FL', 'COLLIER', 'E'],
#  ['GATOR POOLS', '425 24TH ST', 'W PALM BCH', 'FL', 'PALM BEACH', 'E'],
#  ['GATOR POOLS', '5542 32ND AVE. S.W.', 'NAPLES', 'FL', 'COLLIER', 'C'],
#  ['GATOR POOLS', '601 W.S. PARK ST', 'OKEECHOBEE', 'FL', 'OKEECHOBEE', 'E'],
#  ['GATOR POOLS', '8758 PALMETTO CT', 'CAPE CANAVERAL', 'FL', 'BREVARD', 'E'],
#  ['GATOR POOL SERVICES', '3231 SW 3RD AVE', 'CAPE CORAL', 'FL', 'LEE', 'E'],
#  ['GATOR POPS', '28053 LEONA LN', 'WESLEY CHAPEL', 'FL', 'MULTIPLE', 'A'],
#  ['GATOR PORCELAIN', '767 MENDOZA DRIVE', 'ORLANDO', 'FL', 'MULTIPLE', 'E'],
#  ['GATOR PORTABLE BUILDINGS',
#   '205 S DIXIE DRIVE',
#   'HAINES CITY',
#   'FL',
#   'POLK',
#   'A'],
#  ['GATOR POWER AND COMMUNICATION',
#   '2101 S. MILITARY TRAIL',
#   'WEST PALM BEACH',
#   'FL',
#   'MULTIPLE',
#   'E'],
#  ['GATOR POWER GATES', '12547 DENTON AVE.', 'HUDSON', 'FL', 'PASCO', 'E'],
#  ['GATOR POWER PRESSURE WASHING',
#   '4321 BENT TREE BLVD',
#   'SARASOTA',
#   'FL',
#   'SARASOTA',
#   'A'],
#  ['GATOR POWER SYSTEMS',
#   '2101 S. MILITARY TRAIL',
#   'WEST PALM BEACH',
#   'FL',
#   'MULTIPLE',
#   'E'],
#  ['GATOR PRECISION ARMS',
#   '23016 NW 142ND AVE',
#   'HIGH SPRINGS',
#   'FL',
#   'ALACHUA',
#   'A'],
#  ['GATOR PRESS',
#   '4110 SW 34 STREET SUITE 3',
#   'GAINESVILLE',
#   'FL',
#   'ALACHUA',
#   'E'],
#  ['GATOR PRESS', '4110 SW 34TH STREET', 'GAINESVILLE', 'FL', 'ALACHUA', 'C'],
#  ['GATOR PRESS PRINTING',
#   '919 SE 13TH AVENUE',
#   'CAPE CORAL',
#   'FL',
#   'LEE',
#   'A'],
#  ['GATOR PRESSURE', 'P.O. BOX 357321', 'GAINESVILLE', 'FL', 'MULTIPLE', 'E'],
#  ['GATOR PRESSURE CLEANING',
#   '1019 AMBLE LN.',
#   'CLEARWATER',
#   'FL',
#   'PINELLAS',
#   'E'],
#  ['GATOR PRESSURE CLEANING',
#   '1068 NORTHUMBERLAND COURT',
#   'WELLINGTON',
#   'FL',
#   'PALM BEACH',
#   'E'],
#  ['GATOR PRESSURE CLEANING',
#   '1928 TAYLOR AVENUE',
#   'WINTER PARK',
#   'FL',
#   'ORANGE',
#   'E'],
#  ['GATOR PRESSURE CLEANING',
#   '7754 DAWSON COURT',
#   'LAKE WORTH',
#   'FL',
#   'PALM BEACH',
#   'E'],
#  ['GATOR PRESSURE WASHING',
#   '130 NW 9TH TERR APT 107',
#   'GAINESVILLE',
#   'FL',
#   'ALACHUA',
#   'A'],
#  ['GATOR PRESSURE WASHING',
#   '134 STONY POINT DRIVE',
#   'SEBASTIAN',
#   'FL',
#   'INDIAN RIVER',
#   'E'],
#  ['GATOR PRESSURE WASHING',
#   '173 MIDVALE TER',
#   'SEBASTIAN',
#   'FL',
#   'MULTIPLE',
#   'A'],
#  ['GATOR PRESSURE WASHING',
#   '173 MIDVALE TERRACE',
#   'SEBASTIAN',
#   'FL',
#   'INDIAN RIVER',
#   'E'],
#  ['GATOR PRESSURE WASHING',
#   '813 SENATE CT',
#   'TAMPA',
#   'FL',
#   'HILLSBOROUGH',
#   'E'],
#  ['GATOR PRESSURE WASHING',
#   '8205 EDGEMORE LANE',
#   'HUDSON',
#   'FL',
#   'PASCO',
#   'E'],
#  ['GATORPRINTS',
#   '207 TROPIC ISLE DR APT 101',
#   'DELRAY BEACH',
#   'FL',
#   'MULTIPLE',
#   'A'],
#  ['GATOR PRINTS', '3215 OAKLAND RD', 'LAKELAND', 'FL', 'POLK', 'E'],
#  ['GATOR PRINT SHOP', 'PO 358998', 'GAINESVILLE', 'FL', 'MULTIPLE', 'A'],
#  ['GATOR PRIVATE INVESTIGATIONS',
#   '6217 NW 36TH DRIVE',
#   'GAINESVILLE',
#   'FL',
#   'ALACHUA',
#   'E'],
#  ['GATOR PROCESS SERVING',
#   '2901 PALM BAY RD SUITE A',
#   'PALM BAY',
#   'FL',
#   'BREVARD',
#   'E'],
#  ['GATOR PRODUCTIONS',
#   '1850 PROVIDENCE LAKES BLVD.',
#   'BRANDON',
#   'FL',
#   'HILLSBOROUGH',
#   'E'],
#  ['GATOR PRODUCTIONS',
#   '4017 S. LAKEWOOD DRIVE',
#   'PANAMA',
#   'FL',
#   'MULTIPLE',
#   'C'],
#  ['GATOR PRODUCTION SERVICES',
#   '10934 106TH AVE NORTH',
#   'LARGO',
#   'FL',
#   'PINELLAS',
#   'E'],
#  ['GATOR PROFESSIONAL CLEANING SERVICE',
#   '4001 SE 14TH TERRACE',
#   'GAINESVILLE',
#   'FL',
#   'ALACHUA',
#   'E'],
#  ['GATOR PROFESSIONAL CLEANING SERVICES',
#   '1111 NE 21ST COURT',
#   'GAINESVILLE',
#   'FL',
#   'MULTIPLE',
#   'A'],
#  ['GATOR PROFESSIONAL LAWN CARE',
#   '141 ST. GEORGE RD',
#   'WEST MELBOURNE',
#   'FL',
#   'BREVARD',
#   'E'],
#  ['GATOR PROLAWN', 'P O BOX 933', 'ARCHER', 'FL', 'ALACHUA', 'E'],
#  ['GATOR PROMO', '7305 LINKS COURT', 'SARASOTA', 'FL', 'MULTIPLE', 'A'],
#  ['GATOR PROMOTIONS', '1135 WATERVIEW POINT', 'LAKELAND', 'FL', 'POLK', 'E'],
#  ['GATOR PROMOTIONS',
#   '2812 21ST STREET NW',
#   'WINTER HAVEN',
#   'FL',
#   'POLK',
#   'E'],
#  ['GATOR PROMOTIONS', 'PO BOX 662', 'WINTER HAVEN', 'FL', 'POLK', 'E'],
#  ['GATOR PRO OUTDOORS',
#   'P. O. BOX 307',
#   'FELLSMERE',
#   'FL',
#   'INDIAN RIVER',
#   'A'],
#  ['GATOR PROPERTY MAINTENANCE',
#   '1286 N. HAVERHILL RD.',
#   'WEST PALM BEACH',
#   'FL',
#   'PALM BEACH',
#   'E'],
#  ['GATOR PROPERTY MAINTENANCE',
#   '13091 ONEIDA ST.',
#   'SPRING HILL',
#   'FL',
#   'HERNANDO',
#   'E'],
#  ['GATOR PROPERTY MAINTENANCE',
#   '6234 WESTPORT DR.',
#   'PORT RICHEY',
#   'FL',
#   'PASCO',
#   'A'],
#  ['GATOR PROPERTY MANAGEMENT',
#   '1524 EAST BREEZY LN.',
#   'WEST PALM BEACH',
#   'FL',
#   'PALM BEACH',
#   'E'],
#  ['GATOR PROPERTY MANAGEMENT',
#   '2642 CHERRYWOOD LANE',
#   'TITUSVILLE',
#   'FL',
#   'MULTIPLE',
#   'A'],
#  ['GATOR PROPERTY MANAGEMENT',
#   '805 NW 13 STREET',
#   'GAINESVILLE',
#   'FL',
#   'ALACHUA',
#   'E'],
#  ['GATOR PROPERTY MANAGEMENT AND GATOR PROPERTIES',
#   '7215 SW 42ND PLACE',
#   'GAINESVILLE',
#   'FL',
#   'ALACHUA',
#   'E'],
#  ['GATOR PROTO', '2350A NW 71 PLACE', 'GAINESVILLE', 'FL', 'ALACHUA', 'A'],
#  ['GATOR PUBLISHING', '600 BRIDLE WAY', 'LABELLE', 'FL', 'HENDRY', 'E'],
#  ['GATORPULSE.COM', '3527 SW 20TH AVE.', 'GAINESVILLE', 'FL', 'ALACHUA', 'E'],
#  ['GATOR PUMP COMPANY', 'PO BOX 1781', 'LEGIGH ACRES', 'FL', 'MULTIPLE', 'E'],
#  ['GATOR PUMP SERVICE',
#   '9089 CARTER RD.',
#   'BROOKSVILLE',
#   'FL',
#   'MULTIPLE',
#   'E'],
#  ['GATOR Q', '4631 NW 28 ST', 'GAINESVILLE', 'FL', 'ALACHUA', 'A'],
#  ["GATOR Q'S", '14805 NE WALDO RD', 'WALDO', 'FL', 'ALACHUA', 'E'],
#  ['GATOR QUALITY PRESSURE WASHING',
#   '21916 OLD PROVIDENCE ROAD',
#   'ALACHUA',
#   'FL',
#   'ALACHUA',
#   'E'],
#  ['GATOR QUALITY SERVICES',
#   '5041 SW 25TH COURT',
#   'PEMBROKE PARK',
#   'FL',
#   'MULTIPLE',
#   'E'],
#  ['GATOR QUEST GUIDE SERVICES',
#   'POST OFFICE BOX 789',
#   'ARCADIA',
#   'FL',
#   'DESOTO',
#   'A'],
#  ['GATOR RACE TRACK',
#   '10333 FRONT BEACH RD.',
#   'PANAMA CITY BEACH',
#   'FL',
#   'BAY',
#   'E'],
#  ['GATOR RAIDERZ', '6317 ACORN BLVD', 'PUNTA GORDA', 'FL', 'CHARLOTTE', 'E'],
#  ['GATOR RAIDERZ GUIDE SERVICE',
#   '6389 AUSTRIAN BLVD.',
#   'PUNTA GORDA',
#   'FL',
#   'CHARLOTTE',
#   'A'],
#  ['GATOR RAMP SPECIALIST',
#   'P.O. BOX 351269',
#   'JACKSONVILLE',
#   'FL',
#   'DUVAL',
#   'E'],
#  ['GATOR REAL ESTATE INVESTORS ASSOCIATION',
#   '267 LARID DR',
#   'FREEPORT',
#   'FL',
#   'MULTIPLE',
#   'E'],
#  ['GATOR REALTY', '4228 NW 10TH STREET', 'GAINESVILLE', 'FL', 'ALACHUA', 'E'],
#  ['GATOR REALTY',
#   '8895 NORTH MILITARY TRAIL SUITE 101-B',
#   'PALM BEACH GARDENS',
#   'FL',
#   'PALM BEACH',
#   'E'],
#  ['GATOR REALTY',
#   '930 NE JENSEN BEACH BLVD',
#   'JENSEN BEACH',
#   'FL',
#   'MARTIN',
#   'A'],
#  ['GATOR REALTY,LLC',
#   '4228 NW 10TH STREET',
#   'GAINESVILLE',
#   'FL',
#   'ALACHUA',
#   'E'],
#  ['GATOR REALTY OF POLK',
#   '2933 S. FLORIDA AVE.',
#   'LAKELAND',
#   'FL',
#   'POLK',
#   'A'],
#  ['GATOR RECORD', '3220 NW 95 ST', 'MIAMI', 'FL', 'MIAMI-DADE', 'E'],
#  ['GATOR REFINING & BIOFUELS',
#   '1900 CLIFFORD STREET',
#   'FORT MYERS',
#   'FL',
#   'LEE',
#   'A'],
#  ['GATOR REFLECTIONS',
#   '5220 N.W. 34 TERR',
#   'GAINESVILLE',
#   'FL',
#   'ALACHUA',
#   'E'],
#  ['GATOR REIA',
#   '3111 MAHAN DRIVE, SUITE 20-2177',
#   'TALLAHASSEE',
#   'FL',
#   'ALACHUA',
#   'E'],
#  ['GATOR REMAN TRUCKING',
#   '601 N. ASHLEY DR. SUITE 1200',
#   'TAMPA',
#   'FL',
#   'HILLSBOROUGH',
#   'E'],
#  ['GATOR RENTAL GUIDE', 'P O BOX 14257', 'GAINESVILLE', 'FL', 'ALACHUA', 'A'],
#  ['GATOR RENTALS',
#   '14230 WEST NEWBERRY ROAD',
#   'NEWBERRY',
#   'FL',
#   'MULTIPLE',
#   'E'],
#  ['GATOR RENTS', '735 MASON AVE', 'DAYTONA BCH', 'FL', 'VOLUSIA', 'E'],
#  ['GATOR RENTS', '735 MASON AVE', 'DAYTONA BEACH', 'FL', 'VOLUSIA', 'E'],
#  ['GATOR REPAIR & LAWN CARE',
#   '432 NE SOLIDA CIRCLE',
#   'PORT ST LUCIE',
#   'FL',
#   'MULTIPLE',
#   'A'],
#  ['GATOR REPUBLIC CLOTHING CO.',
#   '12781 KINGFISH DRIVE',
#   'TREASURE ISLAND',
#   'FL',
#   'PINELLAS',
#   'E'],
#  ['GATOR RESEARCH AND DEVELOPMENT',
#   '211 SOUTH 24TH STREET, #302',
#   'COCOA BEACH',
#   'FL',
#   'BREVARD',
#   'E'],
#  ['GATOR RESURFACING',
#   'P.O. BOX 290393',
#   'PORT ORANGE',
#   'FL',
#   'MULTIPLE',
#   'E'],
#  ['GATOR ROADSIDE SERVICE',
#   'P.O. BOX 6218',
#   'WEST PALM BEACH',
#   'FL',
#   'MULTIPLE',
#   'E'],
#  ['GATOR ROD CHARTERS',
#   '857 S  MARSHALL LAKE ROAD',
#   'APOPKA',
#   'FL',
#   'ORANGE',
#   'E'],
#  ['GATOR RODS', '27970 LAKE JEM ROAD', 'MT. DORA', 'FL', 'LAKE', 'C'],
#  ['GATOR RODS', '27970 LK JEM RD', 'MOUNT DORA', 'FL', 'MULTIPLE', 'E'],
#  ['GATOR ROOFING SERVICE',
#   '3433 79TH WAY NORTH',
#   'ST. PETERSBURG',
#   'FL',
#   'MULTIPLE',
#   'E'],
#  ['GATOR ROOTER', '7326 S.W. 17TH PLACE', 'GAINESVILLE', 'FL', 'ALACHUA', 'E'],
#  ['GATOR ROVER PARTS', '10925 PONDERSON LN.', 'LAKELAND', 'FL', 'POLK', 'E'],
#  ['GATOR ROYALTY COMFORT HOME CARE',
#   '4707 E. UNIV AVE',
#   'GAINESVILLE',
#   'FL',
#   'ALACHUA',
#   'E'],
#  ['GATOR RUN CLEANING COMPANY',
#   '12809 GETTYSBURG CIRCLE',
#   'ORLANDO',
#   'FL',
#   'MULTIPLE',
#   'E'],
#  ['GATOR RV', '23180 HARPER AVE', 'PORT CHARLOTTE', 'FL', 'CHARLOTTE', 'E'],
#  ['GATORS', '1220 #4 NEWTON ST.', 'KEY WEST', 'FL', 'MONROE', 'E'],
#  ['GATORS 4', '6741 W NEWBERRY RD', 'GAINESVILLE', 'FL', 'ALACHUA', 'A'],
#  ['GATORS 4', '6741 W NEWBERRY ROAD', 'GAINESVILLE', 'FL', 'ALACHUA', 'A'],
#  ['GATORS 4', '6741 W NEWBERRY ROAD', 'GAINESVILLE', 'FL', 'ALACHUA', 'A'],
#  ["GATOR'S AC", '437 SE STARFISH AVE', 'PORT ST LUCIE', 'FL', 'MULTIPLE', 'E'],
#  ['GATOR SALES', '2950 ST AUGUSTINE RD.', 'JACKSONVILLE', 'FL', 'DUVAL', 'E'],
#  ['GATOR,S ALLEY', '1286 SHALLCROSS AVE', 'ORLANDO', 'FL', 'ORANGE', 'E'],
#  ['GATOR SALT DISTRIBUTORS',
#   'P.O. BOX 41',
#   'WEST PALM BEACH',
#   'FL',
#   'PALM BEACH',
#   'E'],
#  ['GATOR SANTANDER',
#   '8800 SW 68TH COURT',
#   'PINECREST',
#   'FL',
#   'MIAMI-DADE',
#   'E'],
#  ["GATOR'S ANTIQUES & COLLECTIBLES",
#   '20960 59TH LANE NORTH',
#   'LOXAHATCHEE',
#   'FL',
#   'PALM BEACH',
#   'A'],
#  ['GATOR SATELLITE', '2000 ALLISON WAY', 'STARKE', 'FL', 'MULTIPLE', 'E'],
#  ['GATOR SATELLITE', '5200 NW 43RD ST', 'GAINEDVILLE', 'FL', 'MULTIPLE', 'A'],
#  ['GATOR SATELLITE', '917 NW 13TH ST', 'GAINESVILLE', 'FL', 'ALACHUA', 'E'],
#  ['GATOR SATELLITE & AUDIO',
#   '11813 ISLAND LAKES LANE',
#   'BOCA RATON',
#   'FL',
#   'PALM BEACH',
#   'E'],
#  ["GATOR'S AUTO SALES",
#   '12410 TAMIAMI TRAIL',
#   'PUNTA GORDA',
#   'FL',
#   'CHARLOTTE',
#   'E'],
#  ['GATOR SAVER GUIDE',
#   '4908 NW 34TH STREET, SUITE 5',
#   'GAINESVILLE',
#   'FL',
#   'MULTIPLE',
#   'E'],
#  ['GATOR SAVER MOVERS',
#   '3324 NW 54TH TERRACE',
#   'GAINESVILLE',
#   'FL',
#   'MULTIPLE',
#   'E'],
#  ["GATOR'S BAR-B-Q AND WINGS",
#   '1500 WEST INTERNATIONAL SPEEDWAY BLVD.',
#   'DAYTONA BEACH',
#   'FL',
#   'VOLUSIA',
#   'E'],
#  ...]

# %%
# open a csv file with append, so old data will not be erased
with open('SwampNamesDates.csv', 'a') as f:
    writer = csv.writer(f)
    writer.writerow(["name", "address", "city", "state", "county", "status", "date"]) # write csv file headers
    for i in range (0, len(data_list)):
        writer.writerow(final_list[i])
